# %%
import pandas as pd
import re

# %%
population = pd.read_csv("C:/WORKSPACE/db/data-files/202409_202409_연령별인구현황_월간.csv")

# %%
population
# Out:
#                                행정구역 2024년09월_계_총인구수 2024년09월_계_연령구간인구수  \
# 0               서울특별시  (1100000000)       9,350,995          9,350,995
# 1            서울특별시 종로구 (1111000000)         138,879            138,879
# 2       서울특별시 종로구 청운효자동(1111051500)          11,143             11,143
# 3         서울특별시 종로구 사직동(1111053000)           8,995              8,995
# 4         서울특별시 종로구 삼청동(1111054000)           2,234              2,234
# ...                             ...             ...                ...
# 1467   경기도 부천시 소사구 소사본동(4119453000)          25,385             25,385
# 1468  경기도 부천시 소사구 소사본1동(4119454000)          28,209             28,209
# 1469    경기도 부천시 소사구 범박동(4119455000)          28,317             28,317
# 1470    경기도 부천시 소사구 옥길동(4119456000)          31,381             31,381
# 1471    경기도 부천시 소사구 괴안동(4119457000)          18,500             18,500
#
#      2024년09월_계_0세 2024년09월_계_1세 2024년09월_계_2세 2024년09월_계_3세 2024년09월_계_4세  \
# ...

# %%
my_region = population[population['행정구역'].str.contains('시흥제1동')].index

# %%
population.iloc[my_region]
# Out:
#                             행정구역 2024년09월_계_총인구수 2024년09월_계_연령구간인구수  \
# 300  서울특별시 금천구 시흥제1동(1154567000)          31,718             31,718
#
#     2024년09월_계_0세 2024년09월_계_1세 2024년09월_계_2세 2024년09월_계_3세 2024년09월_계_4세  \
# 300            98           107           102           108           107
#
#     2024년09월_계_5세 2024년09월_계_6세  ... 2024년09월_여_91세 2024년09월_여_92세  \
# 300           123           136  ...             29             29
#
#     2024년09월_여_93세 2024년09월_여_94세 2024년09월_여_95세 2024년09월_여_96세  \
# 300             15              8              8              7
#
#     2024년09월_여_97세 2024년09월_여_98세 2024년09월_여_99세 2024년09월_여_100세 이상
# 300              3              2            3.0                  4
#
# [1 rows x 310 columns]

# %%
population['2024년09월_계_총인구수'] = population['2024년09월_계_총인구수'].apply(lambda v: int(v.replace(",","")))

# %%
population = population.apply(lambda x: x.replace(",", "").astype(float) if x.dtype == "object" and x.name != '행정구역' else x)
population
# Out:
#                                행정구역  2024년09월_계_총인구수  2024년09월_계_연령구간인구수  \
# 0               서울특별시  (1100000000)        9350995.0           9350995.0
# 1            서울특별시 종로구 (1111000000)         138879.0            138879.0
# 2       서울특별시 종로구 청운효자동(1111051500)          11143.0             11143.0
# 3         서울특별시 종로구 사직동(1111053000)           8995.0              8995.0
# 4         서울특별시 종로구 삼청동(1111054000)           2234.0              2234.0
# ...                             ...              ...                 ...
# 1467   경기도 부천시 소사구 소사본동(4119453000)          25385.0             25385.0
# 1468  경기도 부천시 소사구 소사본1동(4119454000)          28209.0             28209.0
# 1469    경기도 부천시 소사구 범박동(4119455000)          28317.0             28317.0
# 1470    경기도 부천시 소사구 옥길동(4119456000)          31381.0             31381.0
# 1471    경기도 부천시 소사구 괴안동(4119457000)          18500.0             18500.0
#
#       2024년09월_계_0세  2024년09월_계_1세  2024년09월_계_2세  2024년09월_계_3세  \
# ...

# %%
population['2024년09월_계_총인구수'] = population['2024년09월_계_총인구수'].apply(lambda v: int(v.replace(",","")))

# %%
population_copy = population.copy()

# %%
population_copy.columns
# Out:
# Index(['행정구역', '2024년09월_계_총인구수', '2024년09월_계_연령구간인구수', '2024년09월_계_0세',
#        '2024년09월_계_1세', '2024년09월_계_2세', '2024년09월_계_3세', '2024년09월_계_4세',
#        '2024년09월_계_5세', '2024년09월_계_6세',
#        ...
#        '2024년09월_여_91세', '2024년09월_여_92세', '2024년09월_여_93세', '2024년09월_여_94세',
#        '2024년09월_여_95세', '2024년09월_여_96세', '2024년09월_여_97세', '2024년09월_여_98세',
#        '2024년09월_여_99세', '2024년09월_여_100세 이상'],
#       dtype='object', length=310)

# %%
for col in population_copy.columns[1:]:
    population_copy[col] = population_copy[col].map(lambda v : float(str(v).replace(",", "") if v and str(v) != 'nan' else 0))

# %%
import numpy as np

nums = np.array(['123456'])
nums.astype(float)
# Out:
# array([123456.])

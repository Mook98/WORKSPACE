# %%
import matplotlib as mpl

# %%
# ! pip install seaborn

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
flatui = ["#9b59b6", "#3498db", "#95a5a6", "#e74c3c", "#34495e", "#2ecc71"]
sns.palplot(sns.color_palette(flatui))

# %%
colors = ["windows blue", "amber", "greyish", "faded green", "dusty purple"]
sns.palplot(sns.xkcd_palette(colors))

# %%
X = np.linspace(-np.pi, np.pi, 256)
C = np.cos(X)
plt.plot(X, C)
plt.xticks([-np.pi, -np.pi/2, 0,
np.pi/2, np.pi])
plt.yticks([-1, 0, 1],
["Low", "Zero", "High"])
plt.grid(False)
plt.show()
# Out:
# c:\Users\human\.conda\envs\human-da-env\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) Malgun Gothic.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
t = np.arange(0., 5., 0.2)
plt.plot(t, t, 'r--', t, 0.5*t**2, 'bs:',
t, 0.2*t**3, 'g^-')
plt.show()

# %%
plt.plot([1, 4, 9, 16], c="b", lw=5,
ls="--", marker="o", ms=15,
mec="g", mew=5, mfc="r")
# plt.hold(True) # <- 1,5 버전
plt.plot([9, 16, 4, 1], c="k", lw=3,
ls=":", marker="s", ms=10,
mec="m", mew=5, mfc="c")
# plt.hold(False) # <- 1,5 버전
plt.show()

# %%
X = np.linspace(-np.pi, np.pi, 256)
C, S = np.cos(X), np.sin(X)
plt.plot(X, C, label="cosine")
plt.plot(X, S, label="sine")
plt.legend(loc=2)
plt.show()

# %%
x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)
y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)
ax1 = plt.subplot(2, 1, 1)
plt.plot(x1, y1, 'yo-')
plt.title('A tale of 2 subplots')
plt.ylabel('Damped oscillation')
print(ax1)
ax2 = plt.subplot(2, 1, 2)
plt.plot(x2, y2, 'r.-')
plt.xlabel('time (s)')
plt.ylabel('Undamped')
print(ax2)
plt.show()
# Out:
# Axes(0.125,0.53;0.775x0.35)
# Axes(0.125,0.11;0.775x0.35)

# %%
mpl.rc('font', family='malgun gothic')
y = [2, 3, 1]
x = np.arange(len(y))
xlabel = [u'가', u'나', u'다']
plt.bar(x, y)
plt.xticks(x, xlabel)
plt.show()

# %%
x = np.random.randn(5000)
arrays, bins, patches = plt.hist(x,
bins=50)
plt.show()
# Out:
# c:\Users\human\.conda\envs\human-da-env\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) Malgun Gothic.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
X = np.random.normal(0,1,1024)
Y = np.random.normal(0,1,1024)
plt.scatter(X,Y)
plt.show()

# %%
import seaborn as sns

# %%
flatui = ["#9b59b6", "#3498db", "#95a5a6", "#e74c3c", "#34495e", "#2ecc71"]
sns.palplot(sns.color_palette(flatui))

# %%
colors = ["windows blue", "amber", "greyish", "faded green", "dusty purple"]
sns.palplot(sns.xkcd_palette(colors))

# %%
tips = sns.load_dataset("tips")
sns.relplot(x="total_bill", y="tip", data=tips)

# %%
sns.relplot(x="total_bill", y="tip", hue="smoker", style="time", data=tips);
#sns.scatterplot(x="total_bill", y="tip", hue="smoker", style="time",
#data=tips);

# %%
sns.relplot(x="total_bill", y="tip", hue="size", data=tips);

# %%
sns.relplot(x="total_bill", y="tip", size="size", data=tips);

# %%
fmri = sns.load_dataset("fmri")
sns.relplot(x="timepoint", y="signal", kind="line", data=fmri);
# Out:
# c:\Users\human\.conda\envs\human-da-env\Lib\site-packages\seaborn\axisgrid.py:123: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) Malgun Gothic.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\human\.conda\envs\human-da-env\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) Malgun Gothic.
#   func(*args, **kwargs)
# c:\Users\human\.conda\envs\human-da-env\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) Malgun Gothic.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sns.relplot(x="timepoint", y="signal", hue="region", style="event",
kind="line", data=fmri)
# Out:
# c:\Users\human\.conda\envs\human-da-env\Lib\site-packages\seaborn\axisgrid.py:123: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) Malgun Gothic.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\human\.conda\envs\human-da-env\Lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) Malgun Gothic.
#   fig.canvas.draw()
# c:\Users\human\.conda\envs\human-da-env\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) Malgun Gothic.
#   func(*args, **kwargs)
# c:\Users\human\.conda\envs\human-da-env\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) Malgun Gothic.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sns.relplot(x="total_bill", y="tip", hue="smoker", col="time", data=tips)

# %%
sns.relplot(x="timepoint", y="signal", hue="subject",
            col="region", row="event", height=3,
            kind="line", estimator=None, data=fmri)

plt.show()
# Out:
# c:\Users\human\.conda\envs\human-da-env\Lib\site-packages\seaborn\axisgrid.py:123: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) Malgun Gothic.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\human\.conda\envs\human-da-env\Lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) Malgun Gothic.
#   fig.canvas.draw()
# c:\Users\human\.conda\envs\human-da-env\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) Malgun Gothic.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sns.relplot(x="timepoint", y="signal", hue="event", style="event",
            col="subject", col_wrap=5, height=3, linewidth=2.5,
            kind="line", data=fmri.query("region == 'frontal'"))
# Out:
# c:\Users\human\.conda\envs\human-da-env\Lib\site-packages\seaborn\axisgrid.py:123: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) Malgun Gothic.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\human\.conda\envs\human-da-env\Lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) Malgun Gothic.
#   fig.canvas.draw()
# c:\Users\human\.conda\envs\human-da-env\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) Malgun Gothic.
#   func(*args, **kwargs)
# c:\Users\human\.conda\envs\human-da-env\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) Malgun Gothic.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
tips = sns.load_dataset("tips")
sns.catplot(x="day", y="total_bill", data=tips, jitter= True); # jitter : easing overplotting

# %%
sns.catplot(x="day", y="total_bill", hue="sex", kind="swarm", data=tips); # kind="swarm" : easing overplotting

# %%
sns.catplot(x="day", y="total_bill", kind="box", data=tips)

# %%
sns.catplot(x="day", y="total_bill", hue="smoker", kind="box", data=tips)

# %%
sns.catplot(x="day", y="total_bill", hue="sex", kind="violin", split=True,
data=tips)

# %%
g = sns.catplot(x="day", y="total_bill", kind="violin", inner=None,
data=tips)
sns.swarmplot(x="day", y="total_bill", color="k", size=3, data=tips,
ax=g.ax)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
titanic = sns.load_dataset("titanic")
sns.catplot(x="sex", y="survived", hue="class", kind="bar", data=titanic)

# %%
sns.catplot(x="class", y="survived", hue="sex",
            #palette={"male": "g", "female": "m"},
            #markers=["^", "o"], linestyles=["-", "--"],
            kind="point", data=titanic)

# %%
exercise = sns.load_dataset("exercise")
sns.catplot(x="time", y="pulse", hue="kind", col="diet", data=exercise)

# %%
titanic = sns.load_dataset("titanic")
g = sns.catplot(x="alive", col="deck", col_wrap=4,
data=titanic[titanic.deck.notnull()],
kind="count", height=2.5, aspect=.8, )

# %%
x = np.random.normal(size=100)
sns.distplot(x, bins=20, kde=True, rug=True); # kde : kernel density estimation
# Out:
# C:\Users\human\AppData\Local\Temp\ipykernel_13912\765210534.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x, bins=20, kde=True, rug=True); # kde : kernel density estimation
# c:\Users\human\.conda\envs\human-da-env\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) Malgun Gothic.
#   func(*args, **kwargs)
# c:\Users\human\.conda\envs\human-da-env\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) Malgun Gothic.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
iris = sns.load_dataset("iris")
sns.pairplot(iris, hue="species", markers=["o", "s", "^"]) # markers는 hue를 지정했을 경우에만 사용 가능하며 hue에 지정된 컬럼의 데이터 범주의 개수와 일치
plt.show()

# %%
sns.regplot(x="total_bill", y="tip", data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lmplot(x="total_bill", y="tip", data=tips)

# %%
g = sns.FacetGrid(tips, col="sex", hue="smoker")
g.map(plt.scatter, "total_bill", "tip", alpha=.3)
g.add_legend()
plt.show()

# %%
g = sns.PairGrid(iris, hue="species")
g.map_diag(plt.hist)
g.map_offdiag(plt.scatter)
g.add_legend()

# %%
import requests

url = 'https://news.naver.com/breakingnews/section/105/230'
response = requests.get(url)

# %%
response.content.decode('utf-8')
# Out:
# '<!doctype html>\n<html lang="ko" data-useragent="python-requests/2.32.3">\n\t<head>\n\t\t<meta charset="utf-8">\n\t\t<meta http-equiv="X-UA-Compatible" content="IE=edge">\n\t\t<meta name="referrer" contents="always">\n\t\t<meta http-equiv="refresh" content="600">\n\t\t<meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" />\n\t\t<meta property="og:title" content="IT/과학 : 네이버 뉴스">\n\t\t<meta property="og:type" content="website">\n\t\t<meta property="og:url" content="https://news.naver.com/breakingnews/section/105/230">\n\t\t<meta property="og:image" content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png">\n\t\t<meta property="og:description" content="모바일, 인터넷, SNS, 통신 등 IT/과학 분야 뉴스 제공">\n\t\t<meta property="og:article:author" content="네이버">\n\t\t<meta name="twitter:card" content="summary">\n\t\t<meta name="twitter:title" content="IT/과학 : 네이버 뉴스">\n\t\t<meta name="twitter:site" content="네이버 뉴스">\n\t\t<meta name="twitter:creator" content="네이버 뉴스">\n\t\t<meta name="twitter:image" content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png">\n\t\t<meta name="twitter:description" content="모바일, 인터넷, SNS, 통신 등 IT/과학 분야 뉴스 제공">\n\t\t<title>IT/과학 : 네이버 뉴스</title>\n\t\t\t<link rel="stylesheet" href="https://static-nnews.pstatic.net/css/min/20241017/news.css">\n\t\t\t<link rel="shortcut icon" type="image/x-icon" href="https://ssl.pstatic.net/static.news/image/news/m/2023/08/21/favicon.ico" />\n\t\t\t<link rel="apple-touch-icon-precomposed" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxxhpdi_192x192.png" />\n\t\t\t<link rel="apple-touch-icon-precomposed" size="72x72" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_hdpi_72X72.png" />\n\t\t\t<link rel="apple-touch-icon-precomposed" size="96x96" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xhdpi_96x96.png" />\n\t\t\t<link rel="apple-touch-icon-precomposed" size="144x144" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxhpdi_144x144.png" />\n\t\t\t<link rel="apple-touch-icon-precomposed" size="192x192" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxxhpdi_192x192.png" />\n\t\t\t\t\t<script>\n\t\t\tvar bSupportedIntersectionObserver = "IntersectionObserver" in window;\n\t\t</script>\n\t\t<script async src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script>\n\t\t\t\t<script>\n\t\t\tvar g_ssc = nsc = "news.v3_flash";\n\t\t\tvar g_default_area = "itn";\n\n\t\t\tvar svr = "one-service-h-20241018-241018-175642-7c988d6cb7-qzj89";\n\t\t\tvar nelo = {\n\t\t\t\tname : "one-front",\n\t\t\t\turl : "https://kr-col-ext.nelo.navercorp.com/_store",\n\t\t\t\tsampleNumber : 100,\n\t\t\t\tmaxCount : 100,\n\t\t\t\tmaxSendMessage : "로그 전송 최대치 도달"\n\t\t\t};\n\t\t\tvar isGreendot = document.cookie.indexOf("MM_NEW=1") > -1;\n\t\t\tvar isNewGreendot = document.cookie.indexOf("MM_NEW=2") > -1;\n\t\t\tvar domain = "https://n.news.naver.com";\n\t\t\tvar ajaxDomain = "";\n\t\t\tvar newsDomain = "";\n\t\t\tvar layoutName = "section_home_second";\n\t\t\tvar layoutType = "section";\n\t\t\tvar isAvailableDarkMode = false;\n\t\t\tvar moduleLoadStatus = -1;\n\n\t\t\tvar article = {\n\t\t\t\t\n\t\t\t\tofficeId: "",\n\t\t\t\tarticleId: "",\n\t\t\t\tsectionId : "",\n\t\t\t\tgdid: "",\n\t\t\t\ttype: "",\n\t\t\t\tsectionInfo: {\n\t\t\t\t\tfirstSection: "",\n\t\t\t\t\tsecondSection: "",\n\t\t\t\t\tthirdSection: ""\n\t\t\t\t},\n\t\t\t\ttitle: document.title\n\t\t\t};\n\n\n\n\t\t\tvar office = {\n\t\t\t\tisChannel: false,\n\t\t\t\tisPressHome: false,\n\t\t\t\tname : "",\n\t\t\t\tcategory : ""\n\t\t\t};\n\n\t\t\tvar searchQuery = (function() {\n\t\t\t\tvar referrerLink = document.createElement("a");\n\t\t\t\tvar emptySearch = "";\n\n\t\t\t\treferrerLink.href = document.referrer || " ...

# %%
# ! pip install bs4
# Out:
# Collecting bs4
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Requirement already satisfied: beautifulsoup4 in c:\users\human\.conda\envs\human-da-env\lib\site-packages (from bs4) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\human\.conda\envs\human-da-env\lib\site-packages (from beautifulsoup4->bs4) (2.6)
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Installing collected packages: bs4
# Successfully installed bs4-0.0.2

# %%
from bs4 import BeautifulSoup

# %%
html = response.content.decode('utf-8')
soup = BeautifulSoup(html, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html data-useragent="python-requests/2.32.3" lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta contents="always" name="referrer"/>
# <meta content="600" http-equiv="refresh"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport">
# <meta content="IT/과학 : 네이버 뉴스" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="https://news.naver.com/breakingnews/section/105/230" property="og:url"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" property="og:image"/>
# <meta content="모바일, 인터넷, SNS, 통신 등 IT/과학 분야 뉴스 제공" property="og:description"/>
# <meta content="네이버" property="og:article:author"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="IT/과학 : 네이버 뉴스" name="twitter:title"/>
# <meta content="네이버 뉴스" name="twitter:site"/>
# <meta content="네이버 뉴스" name="twitter:creator"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" name="twitter:image"/>
# <meta content="모바일, 인터넷, SNS, 통신 등 IT/과학 분야 뉴스 제공" name="twitter:description"/>
# <title>IT/과학 : 네이버 뉴스</title>
# <link href="https://static-nnews.pstatic.net/css/min/20241017/news.css" rel="stylesheet"/>
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2023/08/21/favicon.ico" rel="shortcut icon" type="image/x-icon">
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxxhpdi_192x192.png" rel="apple-touch-icon-precomposed"/>
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_hdpi_72X72.png" rel="apple-touch-icon-precomposed" size="72x72"/>
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xhdpi_96x96.png" rel="apple-touch-icon-precomposed" size="96x96"/>
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxhpdi_144x144.png" rel="apple-touch-icon-precomposed" size="144x144"/>
# <link href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxxhpdi_192x192.png" rel="apple-touch-icon-precomposed" size="192x192"/>
# <script>
# 			var bSupportedIntersectionObserver = "IntersectionObserver" in window;
# 		</script>
# <script async="" src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script>
# <script>
# 			var g_ssc = nsc = "news.v3_flash";
# 			var g_default_area = "itn";
#
# 			var svr = "one-service-h-20241018-241018-175642-7c988d6cb7-qzj89";
# 			var nelo = {
# 				name : "one-front",
# 				url : "https://kr-col-ext.nelo.navercorp.com/_store",
# 				sampleNumber : 100,
# 				maxCount : 100,
# 				maxSendMessage : "로그 전송 최대치 도달"
# 			};
# 			var isGreendot = document.cookie.indexOf("MM_NEW=1") > -1;
# 			var isNewGreendot = document.cookie.indexOf("MM_NEW=2") > -1;
# 			var domain = "https://n.news.naver.com";
# 			var ajaxDomain = "";
# 			var newsDomain = "";
# 			var layoutName = "section_home_second";
# 			var layoutType = "section";
# 			var isAvailableDarkMode = false;
# 			var moduleLoadStatus = -1;
#
# 			var article = {
#
# 				officeId: "",
# 				articleId: "",
# 				sectionId : "",
# 				gdid: "",
# 				type: "",
# 				sectionInfo: {
# 					firstSection: "",
# 					secondSection: "",
# 					thirdSection: ""
# 				},
# 				title: document.title
# 			};
#
#
#
# 			var office = {
# 				isChannel: false,
# 				isPressHome: false,
# 				name : "",
# 				category : ""
# 			};
#
# 			var searchQuery = (function() {
# 				var referrerLink = document.createElement("a");
# 				var emptySearch = "";
#
# 				referrerLink.href = document.referrer || "";
#
# 				if (referrerLink.host.indexOf("search.naver.com") === -1) {
# 					return emptySearch;
# 				}
#
# 				return decodeURIComponent(
# 					(
# 						referrerLink.search.match(/(?:\?|&)query\=([^&]+)/) || [ null, emptySearch ]
# 					)[1].replace(/\+/g, " ")
# 				);
# 			})();
#
# 			var divIds = [];
# 			var syncDivIds = [];
# 			var syncDivIdsForNonArticle = [];
#
# 			var unitIds = [];
# 			var syncUnitIds = [];
# 			var syncUnitIdsForNonArticle = [];
#
# 			window.gladsdk = window.gladsdk || { cmd: [] };
# 			gladsdk.cmd.push(function() {
# 				gladsdk.setGlobalConfig({ enablePersistAd: true });
#
# 				var adInfoList = [];
#
# 				adInfoList.push({
# 					seq: 1,
# 					unitId: "p_news_newslist",
# 					sync: false,
# 					mobileOnly: false,
# 					article: false,
# 					directSalesPct: "",
# 					calp: false,
# 					hasSid1: true
# 				});
# 				adInfoList.push({
# 					seq: 2,
# 					unitId: "p_news_sidebox",
# 					sync: false,
# 					mobileOnly: false,
# 					article: false,
# 					directSalesPct: "",
# 					calp: true,
# 					hasSid1: false
# 				});
#
# 				var userAgent = navigator.userAgent.toLowerCase();
#
# 				for (var i = 0; i < adInfoList.length; i++) {
# 					var adInfo = adInfoList[i];
#
# 					var divId = "nmap_c_" + article.officeId + "_" + article.articleId + "_" + article.sectionId + "_" + adInfo.seq;
#
# 					var unitId = adInfo.unitId;
# 					var mobileOnly = adInfo.mobileOnly;
# 					var sync = adInfo.sync;
# 					var isArticle = adInfo.article;
# 					var directSalesPct = adInfo.directSalesPct;
# 					var calp = adInfo.calp;
# 					var hasSid1 = adInfo.hasSid1;
#
# 					if (mobileOnly == true) {
# 						if (/iphone|android|ipod/.test(userAgent) == false) {
# 							continue;
# 						}
# 					}
#
# 					var customParam = {
# 						sid1: article.sectionId,
# 						oid: article.officeId,
# 						gdid: article.gdid,
# 						pk: searchQuery,
# 						directSalesPct: directSalesPct
# 					};
#
# 					if (calp == true) {
# 						customParam.calp = "shome";
# 					}
# 					if (hasSid1 == true) {
# 						customParam.sid1 = "105";
# 					}
#
# 					var adUnit = {
# 						adUnitId: unitId,
# 						adSlotElementId: divId,
# 						customParam: customParam
# 					};
#
# 					if (sync == true) {
# 						syncUnitIds.push(unitId);
# 						syncDivIds.push(divId);
#
# 						if (isArticle == false) {
# 							syncUnitIdsForNonArticle.push(unitId);
# 							syncDivIdsForNonArticle.push(divId);
# 						}
# 					} else {
# 						unitIds.push(unitId);
# 						divIds.push(divId);
# 					}
#
# 					gladsdk.defineAdSlot(adUnit);
# 				}
#
# 			});
# 			window.__htExternalUrl = window.__htExternalUrl || {};
# 		</script>
# <script src="https://static-nnews.pstatic.net/js/min/20241018a/common.min.js"></script>
# </link></meta></head>
# <body class="n_news_mnews fs1 as_mp_layout as_section_home" style="color: #;">
# <div class="end_container">
# <div class="u_skip"><a href="#ct">본문 바로가기</a></div>
# <header class="as_gnb_mnews as_type_section" role="banner">
# <div class="header_inner">
# <div class="Ngnb">
# <div class="Ngnb_inner">
# <div class="Ngnb_both">
# <div class="Ngnb_left">
# <span class="Ngnb_logo"><a class="Nlogo_link _LINK" data-clk="gnb.naver" data-pc-url="https://www.naver.com/" data-url="https://m.naver.com/" href="https://m.naver.com/"><span class="Nicon_logo">NAVER</span></a></span>
# <div class="Ngnb_service">
# <h1 class="Nservice_item"><a class="_LINK" data-clk="gnb.news" data-pc-url="https://news.naver.com/" data-url="https://m.news.naver.com" href="https://m.news.naver.com"><span class="Nicon_service">뉴스</span></a></h1>
# <span class="Nservice_subitem">
# <a class="_LINK" data-clk="gnb.entertain" data-pc-url="https://entertain.naver.com/home" data-url="https://m.entertain.naver.com" href="https://m.entertain.naver.com">
# <span class="Nicon_family Nicon_entertain">연예</span>
# </a>
# </span>
# <span class="Nservice_subitem">
# <a class="_LINK" data-clk="gnb.sports" data-pc-url="https://sports.news.naver.com/index" data-url="https://m.sports.naver.com" href="https://m.sports.naver.com">
# <span class="Nicon_family Nicon_sports">스포츠</span>
# </a>
# </span>
# <span class="Nservice_subitem">
# <a data-clk="gnb.weather" href="https://weather.naver.com">
# <span class="Nicon_family Nicon_weather">날씨</span>
# </a>
# </span>
# <span class="Nservice_subitem">
# <a data-clk="gnb.premium" href="https://contents.premium.naver.com">
# <span class="Nicon_family Nicon_premium">프리미엄</span>
# </a>
# </span>
# </div>
# </div>
# <div class="Ngnb_right">
# <div class="Ngnb_group">
# <div class="gnb_dark_type2" id="gnb"></div>
# </div>
# <div class="Ngnb_search _SEARCH_WRAP is_hidden"></div>
# <div class="Ngnb_tool">
# <a class="Ntool_button _SEARCH_CONTENT_TOGGLE_BUTTON" data-clk="gnb.scho" href="javascript:;"><span class="Nicon_search">검색</span></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="Nlnb" data-scroll-fixed="true" id="_LNB_PARENT_WRAP" style="z-index:3000;">
# <div class="Nlnb_menu Ntype_scroll" id="_LNB_WRAP">
# <div class="Nlnb_menu_inner" id="_LNB">
# <ul class="Nlnb_menu_list" role="tablist">
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.press" href="https://news.naver.com/" role="tab"><span class="Nitem_link_menu">언론사별</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.pol" href="https://news.naver.com/section/100" role="tab"><span class="Nitem_link_menu">정치</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.eco" href="https://news.naver.com/section/101" role="tab"><span class="Nitem_link_menu">경제</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.soc" href="https://news.naver.com/section/102" role="tab"><span class="Nitem_link_menu">사회</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.lif" href="https://news.naver.com/section/103" role="tab"><span class="Nitem_link_menu">생활/문화</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM is_active" role="presentation">
# <a aria-selected="true" class="Nitem_link" data-clk="lnb.it" href="https://news.naver.com/section/105" role="tab"><span class="Nitem_link_menu">IT/과학</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.wor" href="https://news.naver.com/section/104" role="tab"><span class="Nitem_link_menu">세계</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.rank" href="https://news.naver.com/main/ranking/popularDay.naver?mid=etc&amp;sid1=111" role="tab"><span class="Nitem_link_menu">랭킹</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.paper" href="https://news.naver.com/newspaper/home" role="tab"><span class="Nitem_link_menu">신문보기</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.opi" href="https://news.naver.com/main/opinion/home.naver" role="tab"><span class="Nitem_link_menu">오피니언</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.tv" href="https://news.naver.com/main/tv/index.naver?mid=tvh" role="tab"><span class="Nitem_link_menu">TV</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.fact" href="https://news.naver.com/main/factcheck/main.naver" role="tab"><span class="Nitem_link_menu">팩트체크</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.algo" href="https://media.naver.com/algorithm" role="tab"><span class="Nitem_link_menu">알고리즘 안내</span></a>
# </li>
# <li class="Nlist_item _LNB_ITEM" role="presentation">
# <a aria-selected="false" class="Nitem_link" data-clk="lnb.correct" href="https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb" role="tab"><span class="Nitem_link_menu">정정보도 모음</span></a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </header>
# <hr/>
# <script>
# 	var svt = "20241023123546.212";
# 	var timestamp = svt.substr(0, 8);
# 	var isLogin = false;
# 	var uhv = "";
#
# 	var service = {
# 		news: false,
# 		entertain: false,
# 		sports: false,
# 		mnews: true,
# 		newsType: true
# 	};
# 	var serviceName = "mnews";
#
# 	var nilNtmUrl = "https://ntm.pstatic.net/scripts/ntm_b7032129a433.js";
#
# 	var envPhase = "production";
# 	var isProduction = true;
#
# 	var gnb_service = "news";
# 	var gnb_logout = encodeURIComponent(location.href);
# 	var gnb_template = "gnb_utf8";
# 	var gnb_brightness = 3;
# 	var gnb_item_hide_option = 128;
# </script>
# <div class="ct_wrap" id="ct_wrap">
# <div class="ct_lnb">
# <div class="ct_lnb_inner">
# <strong class="ct_lnb_date">10.23(수)</strong>
# <ul class="ct_lnb_side">
# <li class="ct_lnb_side_item">
# <a class="ct_lnb_side_link" data-clk="slb.allmedia" href="https://news.naver.com/main/officeList.naver">전체 언론사</a>
# </li>
# <li class="ct_lnb_side_item">
# <a class="ct_lnb_side_link" data-clk="slb.newsstand" href="https://newsstand.naver.com/" target="_blank">뉴스스탠드</a>
# </li>
# <li class="ct_lnb_side_item">
# <a class="ct_lnb_side_link" data-clk="slb.library" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank">라이브러리</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="ct_scroll_wrapper">
# <div class="column0">
# <div class="ct_snb">
# <h2 class="ct_snb_h2">
# <a class="ct_snb_h2_a" data-clk="lmn_itn.home" href="/section/105">IT/과학</a>
# </h2>
# <ul class="ct_snb_nav">
# <li class="ct_snb_nav_item">
# <a class="ct_snb_nav_item_link" data-clk="lmn_itn.mnl" data-rank="1" href="/breakingnews/section/105/731">모바일</a>
# </li>
# <li class="ct_snb_nav_item">
# <a class="ct_snb_nav_item_link" data-clk="lmn_itn.mnl" data-rank="2" href="/breakingnews/section/105/226">인터넷/SNS</a>
# </li>
# <li class="ct_snb_nav_item">
# <a class="ct_snb_nav_item_link" data-clk="lmn_itn.mnl" data-rank="3" href="/breakingnews/section/105/227">통신/뉴미디어</a>
# </li>
# <li class="ct_snb_nav_item is_selected">
# <a class="ct_snb_nav_item_link" data-clk="lmn_itn.mnl" data-rank="4" href="/breakingnews/section/105/230">IT 일반</a>
# </li>
# <li class="ct_snb_nav_item">
# <a class="ct_snb_nav_item_link" data-clk="lmn_itn.mnl" data-rank="5" href="/breakingnews/section/105/732">보안/해킹</a>
# </li>
# <li class="ct_snb_nav_item">
# <a class="ct_snb_nav_item_link" data-clk="lmn_itn.mnl" data-rank="6" href="/breakingnews/section/105/283">컴퓨터</a>
# </li>
# <li class="ct_snb_nav_item">
# <a class="ct_snb_nav_item_link" data-clk="lmn_itn.mnl" data-rank="7" href="/breakingnews/section/105/229">게임/리뷰</a>
# </li>
# <li class="ct_snb_nav_item">
# <a class="ct_snb_nav_item_link" data-clk="lmn_itn.mnl" data-rank="8" href="/breakingnews/section/105/228">과학 일반</a>
# </li>
# </ul>
# <div class="ct_snb_banner _LAZY_LOADING_WRAP _LAZY_LOADING_ERROR_HIDE">
# <a data-clk="lmn_itn.pmb" data-rank="1" href="https://media.naver.com/algorithm">
# <img alt="AI 뉴스 알고리즘 안내" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://imgnews.pstatic.net/image/upload/item/2023/07/10/184436024_banner_left.png" height="74" style="display: none;" width="71"/>
# </a>
# </div>
# <div class="ct_snb_banner _LAZY_LOADING_WRAP _LAZY_LOADING_ERROR_HIDE">
# <a data-clk="lmn_itn.pmb" data-rank="2" href="https://contents.premium.naver.com/">
# <img alt="프리미엄콘텐츠" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://imgnews.pstatic.net/image/upload/item/2021/05/28/233112515_DA%2540PC%25B4%25BA%25BD%25BA%25C1%25C2%25C3%25F8.png" height="74" style="display: none;" width="71"/>
# </a>
# </div>
# </div>
# </div>
# <div class="newsct_wrapper _GRID_TEMPLATE_COLUMN _STICKY_CONTENT" id="newsct" role="main"><div class="section_title _CALENDAR_WRAP">
# <div class="section_title_inner">
# <h3 class="section_title_h">IT 일반</h3>
# <div class="section_title_sort">
# <button class="section_title_btn is_selected _LINK _CALENDAR_TODAY_LINK" data-clk="alistlatest" data-url="/breakingnews/section/105/230" type="button">최신순</button>
# <button class="section_title_btn is_closed _CALENDAR_LAYER_TOGGLE" data-clk="caltoggle" type="button">날짜별</button>
# </div>
# </div>
# <div class="calendar">
# <div class="calendar_layer is_hidden _CALENDAR" data-selected-date="20241023" data-start-date="20141023"></div>
# <script class="_CALENDAR_TEMPLATE" type="x-tmpl-mustache">
# 		<div class="calendar_layer_head">
# 			<button type="button" class="calendar_layer_prev clndr-previous-button">
# 				<span class="blind">이전</span>
# 			</button>
# 			<div class="calendar_layer_date">
# 				<strong class="calendar_layer_date_text">{{year}}.{{monthInNumber}}</strong>
# 				<button type="button" class="calendar_layer_today _CALENDAR_TODAY" data-clk="caltoday">오늘</button>
# 			</div>
# 			<button type="button" class="calendar_layer_next clndr-next-button">
# 				<span class="blind">다음</span>
# 			</button>
# 		</div>
# 		<div class="calendar_layer_body">
# 			<table>
# 				<caption><span class="blind">캘린더</span></caption>
# 				<thead>
# 					<tr>
# 						{{#daysOfTheWeek}}
# 						<th scope="col">{{.}}</th>
# 						{{/daysOfTheWeek}}
# 					</tr>
# 				</thead>
# 				<tbody>
# 					{{#chunkedDays}}
# 					<tr>
# 						{{#.}}
# 						<td class="{{classes}}">
# 							<a href="javascript:;" class="calendar_a" data-clk="caldate">{{day}}</a>
# 						</td>
# 						{{/.}}
# 					</tr>
# 					{{/chunkedDays}}
# 				</tbody>
# 			</table>
# 			<button type="button" class="calendar_layer_close _CALENDAR_LAYER_TOGGLE" data-clk="calclose">
# 				<span class="blind">닫기</span>
# 			</button>
# 		</div>
# 		</script>
# </div>
# </div>
# <div class="section_latest">
# <div class="section_component as_section_article_list _PERSIST_CONTENT" data-persist="SECTION_ARTICLE_LIST_FOR_LATEST">
# <div class="section_latest_article _CONTENT_LIST _PERSIST_META" data-cluid="" data-cursor="2024102311315658085" data-cursor-name="next" data-date="" data-has-next="true" data-nclk="alist" data-page-no="1" data-persist="SECTION_ARTICLE_LIST_FOR_LATEST_META" data-persist-meta-restore="true" data-sid="105" data-sid2="230" data-template="SECTION_ARTICLE_LIST_FOR_LATEST">
# <div class="section_article _TEMPLATE" data-template-id="SECTION_ARTICLE_LIST_FOR_LATEST">
# <ul class="sa_list">
# <li class="sa_item _LAZY_LOADING_WRAP">
# <div class="sa_item_inner">
# <div class="sa_item_flex">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="alist" data-gdid="08138263_000000000000000007862390" data-imp-url="https://n.news.naver.com/mnews/article/421/0007862390" data-rank="1" href="https://n.news.naver.com/mnews/article/421/0007862390">
# <img alt="군수자원 관리 효율화…삼성SDS, 공군과 디지털전환 MOU" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/421/2024/10/23/7862390.jpg?type=nf220_150" height="75" onerror="this.outerHTML='&lt;span class=&quot;noimage&quot;&gt;&lt;/span&gt;'" style="display: none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title _NLOG_IMPRESSION" data-clk="alist" data-gdid="08138263_000000000000000007862390" data-imp-url="https://n.news.naver.com/mnews/article/421/0007862390" data-rank="1" href="https://n.news.naver.com/mnews/article/421/0007862390">
# <strong class="sa_text_strong">군수자원 관리 효율화…삼성SDS, 공군과 디지털전환 MOU</strong>
# </a>
# <div class="sa_text_lede">삼성SDS(018260)는 충남 계룡대 공군본부에서 공군본부와 군수혁신 업무협약(MOU)을 23일 체결했다. 공군 군수관리시스템의 디지털 전환, 공급망 관리 설루션을 통한 군수자원 수요 예측·분석이 골자다. 삼성SD</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">뉴스1</div>
# <div class="sa_text_datetime is_recent">
# <b>2분전</b>
# </div>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news421,0007862390" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/421/0007862390" style="display: none;"></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _LAZY_LOADING_WRAP">
# <div class="sa_item_inner">
# <div class="sa_item_flex">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="alist" data-gdid="08138263_000000000000000007862389" data-imp-url="https://n.news.naver.com/mnews/article/421/0007862389" data-rank="2" href="https://n.news.naver.com/mnews/article/421/0007862389">
# <img alt='카카오-엔비디아와 맞손…"카나나 알파팀과 AI 모델 만든다"' class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/421/2024/10/23/7862389.jpg?type=nf220_150" height="75" onerror="this.outerHTML='&lt;span class=&quot;noimage&quot;&gt;&lt;/span&gt;'" style="display: none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title _NLOG_IMPRESSION" data-clk="alist" data-gdid="08138263_000000000000000007862389" data-imp-url="https://n.news.naver.com/mnews/article/421/0007862389" data-rank="2" href="https://n.news.naver.com/mnews/article/421/0007862389">
# <strong class="sa_text_strong">카카오-엔비디아와 맞손…"카나나 알파팀과 AI 모델 만든다"</strong>
# </a>
# <div class="sa_text_lede">카카오(035720)가 인공지능(AI) 생태계 강화를 위해 엔비디아와 협력한다. 엔비디아는 카카오의 AI 모델 개발중심 조직 '카나나 알파'와 AI 모델을 만들고 있고, AI 서비스 중심 조직 '카나나 엑스'와는 인</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">뉴스1</div>
# <div class="sa_text_datetime is_recent">
# <b>4분전</b>
# </div>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news421,0007862389" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/421/0007862389" style="display: none;"></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _LAZY_LOADING_WRAP">
# <div class="sa_item_inner">
# <div class="sa_item_flex">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="alist" data-gdid="8800010E_000000000000000002377909" data-imp-url="https://n.news.naver.com/mnews/article/016/0002377909" data-rank="3" href="https://n.news.naver.com/mnews/article/016/0002377909">
# <img alt="지구 생명체, 외계서 왔나…운석 충돌 생명 기원 근거 나와" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/016/2024/10/23/2377909.jpg?type=nf220_150" height="75" onerror="this.outerHTML='&lt;span class=&quot;noimage&quot;&gt;&lt;/span&gt;'" style="display: none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title _NLOG_IMPRESSION" data-clk="alist" data-gdid="8800010E_000000000000000002377909" data-imp-url="https://n.news.naver.com/mnews/article/016/0002377909" data-rank="3" href="https://n.news.naver.com/mnews/article/016/0002377909">
# <strong class="sa_text_strong">지구 생명체, 외계서 왔나…운석 충돌 생명 기원 근거 나와</strong>
# </a>
# <div class="sa_text_lede">약 32억년 전 지구에 초대형 운석이 충돌, 생명체 탄생의 원동력이 됐을 수 있다는 연구 결과가 나왔다. 이 운석은 박테리아 생명체를 풍부하게 하는 성분을 자극, 결과적으로 지구에 생명체가 번성할 수 있는 환경을 조</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">헤럴드경제</div>
# <div class="sa_text_datetime is_recent">
# <b>9분전</b>
# </div>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news016,0002377909" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/016/0002377909" style="display: none;"></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _LAZY_LOADING_WRAP">
# <div class="sa_item_inner">
# <div class="sa_item_flex">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="alist" data-gdid="8800011E_000000000000000002349678" data-imp-url="https://n.news.naver.com/mnews/article/092/0002349678" data-rank="4" href="https://n.news.naver.com/mnews/article/092/0002349678">
# <img alt="[유통 픽] 스타벅스, 다음 달부터 겨울 e-프리퀀시 시작 外" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/092/2024/10/23/2349678.jpg?type=nf220_150" height="75" onerror="this.outerHTML='&lt;span class=&quot;noimage&quot;&gt;&lt;/span&gt;'" style="display: none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title _NLOG_IMPRESSION" data-clk="alist" data-gdid="8800011E_000000000000000002349678" data-imp-url="https://n.news.naver.com/mnews/article/092/0002349678" data-rank="4" href="https://n.news.naver.com/mnews/article/092/0002349678">
# <strong class="sa_text_strong">[유통 픽] 스타벅스, 다음 달부터 겨울 e-프리퀀시 시작 外</strong>
# </a>
# <div class="sa_text_lede">스타벅스가 다음 달 1일부터 12월 31일까지 ‘2024 겨울 e-프리퀀시’ 이벤트를 진행한다. 회사는 사이렌 오더 혹은 매장에서 미션 음료 3잔을 포함해 제조 음료 총 17잔을 구매하고 e-스티커 적립을 완성한 고</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">지디넷코리아</div>
# <div class="sa_text_datetime is_recent">
# <b>14분전</b>
# </div>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news092,0002349678" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/092/0002349678" style="display: none;"></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _LAZY_LOADING_WRAP">
# <div class="sa_item_inner">
# <div class="sa_item_flex">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="alist" data-gdid="880000EA_000000000000000003250313" data-imp-url="https://n.news.naver.com/mnews/article/030/0003250313" data-rank="5" href="https://n.news.naver.com/mnews/article/030/0003250313">
# <img alt="오픈AI, 美 민주당 백악관 출신 인사 잇단 영입" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/030/2024/10/23/3250313.jpg?type=nf220_150" height="75" onerror="this.outerHTML='&lt;span class=&quot;noimage&quot;&gt;&lt;/span&gt;'" style="display: none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title _NLOG_IMPRESSION" data-clk="alist" data-gdid="880000EA_000000000000000003250313" data-imp-url="https://n.news.naver.com/mnews/article/030/0003250313" data-rank="5" href="https://n.news.naver.com/mnews/article/030/0003250313">
# <strong class="sa_text_strong">오픈AI, 美 민주당 백악관 출신 인사 잇단 영입</strong>
# </a>
# <div class="sa_text_lede">오픈AI가 미 대선을 앞두고 민주당 백악관 출신 인사들을 잇달아 영입하고 있다. 22일(현지시간) 뉴욕타임스(NYT) 등 외신에 따르면, 오픈AI는 최근 듀크대 경영대학원 경영 공공 정책 교수인 애런 채터지를 수석 </div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">전자신문</div>
# <div class="sa_text_datetime is_recent">
# <b>16분전</b>
# </div>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news030,0003250313" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/030/0003250313" style="display: none;"></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _LAZY_LOADING_WRAP">
# <div class="sa_item_inner">
# <div class="sa_item_flex">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="alist" data-gdid="08138263_000000000000000007862376" data-imp-url="https://n.news.naver.com/mnews/article/421/0007862376" data-rank="6" href="https://n.news.naver.com/mnews/article/421/0007862376">
# <img alt='"재사용 힘든 차세대 발사체, 메탄 엔진 연구에 우주청 나서야"' class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/421/2024/10/23/7862376.jpg?type=nf220_150" height="75" onerror="this.outerHTML='&lt;span class=&quot;noimage&quot;&gt;&lt;/span&gt;'" style="display: none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title _NLOG_IMPRESSION" data-clk="alist" data-gdid="08138263_000000000000000007862376" data-imp-url="https://n.news.naver.com/mnews/article/421/0007862376" data-rank="6" href="https://n.news.naver.com/mnews/article/421/0007862376">
# <strong class="sa_text_strong">"재사용 힘든 차세대 발사체, 메탄 엔진 연구에 우주청 나서야"</strong>
# </a>
# <div class="sa_text_lede">"케로신(등유) 엔진 기반의 한국형 차세대발사체는 그을음이 많이 나와 재사용성이 떨어진다. 반면 전 세계 트렌드는 그을음이 나오지 않는 메탄·수소 기반 재사용 발사체다." 23일 김민석 항공우주산업진흥협회(KAIA)</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">뉴스1</div>
# <div class="sa_text_datetime is_recent">
# <b>17분전</b>
# </div>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news421,0007862376" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/421/0007862376" style="display: none;"></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="section_article _TEMPLATE" data-template-id="SECTION_ARTICLE_LIST_FOR_LATEST">
# <ul class="sa_list">
# <li class="sa_item _LAZY_LOADING_WRAP">
# <div class="sa_item_inner">
# <div class="sa_item_flex">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="alist" data-gdid="880000BC_000000000000000005383983" data-imp-url="https://n.news.naver.com/mnews/article/009/0005383983" data-rank="7" href="https://n.news.naver.com/mnews/article/009/0005383983">
# <img alt="삼성 TV “배경화면이 말만하면 원하는 대로”...2024년형 모델에 적용" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/009/2024/10/23/5383983.jpg?type=nf220_150" height="75" onerror="this.outerHTML='&lt;span class=&quot;noimage&quot;&gt;&lt;/span&gt;'" style="display: none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title _NLOG_IMPRESSION" data-clk="alist" data-gdid="880000BC_000000000000000005383983" data-imp-url="https://n.news.naver.com/mnews/article/009/0005383983" data-rank="7" href="https://n.news.naver.com/mnews/article/009/0005383983">
# <strong class="sa_text_strong">삼성 TV “배경화면이 말만하면 원하는 대로”...2024년형 모델에 적용</strong>
# </a>
# <div class="sa_text_lede">AI TV에 생성형 배경화면 도입 2024년형 네오(Neo) QLED와 QLED 모델 삼성전자가 인공지능(AI) 기술을 기반으로 한 ‘생성형 배경화면(Generative Wallpaper)’ 기능을 선보인다고 23일</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">매일경제</div>
# <div class="sa_text_datetime is_recent">
# <b>24분전</b>
# </div>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news009,0005383983" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/009/0005383983" style="display: none;"></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _LAZY_LOADING_WRAP">
# <div class="sa_item_inner">
# <div class="sa_item_flex">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="alist" data-gdid="880000D8_000000000000000015000955" data-imp-url="https://n.news.naver.com/mnews/article/001/0015000955" data-rank="8" href="https://n.news.naver.com/mnews/article/001/0015000955">
# <img alt='"엔비디아, 태국 투자계획 발표할 것…12월 젠슨 황 방문"' class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/001/2024/10/23/15000955.jpg?type=nf220_150" height="75" onerror="this.outerHTML='&lt;span class=&quot;noimage&quot;&gt;&lt;/span&gt;'" style="display: none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title _NLOG_IMPRESSION" data-clk="alist" data-gdid="880000D8_000000000000000015000955" data-imp-url="https://n.news.naver.com/mnews/article/001/0015000955" data-rank="8" href="https://n.news.naver.com/mnews/article/001/0015000955">
# <strong class="sa_text_strong">"엔비디아, 태국 투자계획 발표할 것…12월 젠슨 황 방문"</strong>
# </a>
# <div class="sa_text_lede">태국 정부 공개…올해 태국 투자 유치 10년 만에 최대 박진형 특파원 = 세계 빅테크(거대 정보기술기업)들이 잇따라 태국 등 동남아에 대해 대규모 투자에 나서는 가운데 미국 반도체 기업 엔비디아도 태국 투자 계획을 </div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">연합뉴스</div>
# <div class="sa_text_datetime is_recent">
# <b>31분전</b>
# </div>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news001,0015000955" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/001/0015000955" style="display: none;"></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _LAZY_LOADING_WRAP">
# <div class="sa_item_inner">
# <div class="sa_item_flex">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="alist" data-gdid="880000BC_000000000000000005383980" data-imp-url="https://n.news.naver.com/mnews/article/009/0005383980" data-rank="9" href="https://n.news.naver.com/mnews/article/009/0005383980">
# <img alt="퀄컴·구글, 생성형AI 기반 디지털 콕핏 개발 나섰다" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/009/2024/10/23/5383980.jpg?type=nf220_150" height="75" onerror="this.outerHTML='&lt;span class=&quot;noimage&quot;&gt;&lt;/span&gt;'" style="display: none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title _NLOG_IMPRESSION" data-clk="alist" data-gdid="880000BC_000000000000000005383980" data-imp-url="https://n.news.naver.com/mnews/article/009/0005383980" data-rank="9" href="https://n.news.naver.com/mnews/article/009/0005383980">
# <strong class="sa_text_strong">퀄컴·구글, 생성형AI 기반 디지털 콕핏 개발 나섰다</strong>
# </a>
# <div class="sa_text_lede">퀄컴, 구글과 자동차 디지털 전환 협력 발표 생성형 AI 기반 차량 내 경험 목표 스냅드래곤 디지털 섀시 및 AAOS 통합 제미나이 나노 기반 엣지 AI 기술 적용 퀄컴은 구글과 함께 생성형 AI 기반의 차량 내 콕</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">매일경제</div>
# <div class="sa_text_datetime is_recent">
# <b>31분전</b>
# </div>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news009,0005383980" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/009/0005383980" style="display: none;"></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _LAZY_LOADING_WRAP">
# <div class="sa_item_inner">
# <div class="sa_item_flex">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="alist" data-gdid="8812A0A8_000000000000000002884560" data-imp-url="https://n.news.naver.com/mnews/article/119/0002884560" data-rank="10" href="https://n.news.naver.com/mnews/article/119/0002884560">
# <img alt="우체국 실손보험금 청구 쉬워졌다…‘실손보험금 청구 간소화 서비스’ 시행" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/119/2024/10/23/2884560.jpg?type=nf220_150" height="75" onerror="this.outerHTML='&lt;span class=&quot;noimage&quot;&gt;&lt;/span&gt;'" style="display: none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title _NLOG_IMPRESSION" data-clk="alist" data-gdid="8812A0A8_000000000000000002884560" data-imp-url="https://n.news.naver.com/mnews/article/119/0002884560" data-rank="10" href="https://n.news.naver.com/mnews/article/119/0002884560">
# <strong class="sa_text_strong">우체국 실손보험금 청구 쉬워졌다…‘실손보험금 청구 간소화 서비스’ 시행</strong>
# </a>
# <div class="sa_text_lede">이달 25일부터 질병과 상해 등으로 병원 진료를 받은 뒤 진료비 관련 서류 발급없이 우체국 실손보험금을 간편하게 청구할 수 있게 된다. 우정사업본부는 ‘우체국예금·보험에 관한 법률’ 개정안 시행에 따라 25일부터 민</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">데일리안</div>
# <div class="sa_text_datetime is_recent">
# <b>34분전</b>
# </div>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news119,0002884560" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/119/0002884560" style="display: none;"></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _LAZY_LOADING_WRAP">
# <div class="sa_item_inner">
# <div class="sa_item_flex">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="alist" data-gdid="880000E7_000000000000000005866014" data-imp-url="https://n.news.naver.com/mnews/article/018/0005866014" data-rank="11" href="https://n.news.naver.com/mnews/article/018/0005866014">
# <img alt="대한민국 과학기술유공자 2인, 국립묘지 안장 결정" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/018/2024/10/23/5866014.jpg?type=nf220_150" height="75" onerror="this.outerHTML='&lt;span class=&quot;noimage&quot;&gt;&lt;/span&gt;'" style="display: none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title _NLOG_IMPRESSION" data-clk="alist" data-gdid="880000E7_000000000000000005866014" data-imp-url="https://n.news.naver.com/mnews/article/018/0005866014" data-rank="11" href="https://n.news.naver.com/mnews/article/018/0005866014">
# <strong class="sa_text_strong">대한민국 과학기술유공자 2인, 국립묘지 안장 결정</strong>
# </a>
# <div class="sa_text_lede">과학기술정보통신부는 지난 10일 진행된 국가보훈부 ‘제19회 국립묘지 안장대상 심의위원회’ 심의 결과, 국가·사회 발전을 위해 공헌한 故 김재관·박상대 박사가 국립묘지 안장 대상자로 결정됐다고 23일 밝혔다. 과기정</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">이데일리</div>
# <div class="sa_text_datetime is_recent">
# <b>34분전</b>
# </div>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news018,0005866014" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/018/0005866014" style="display: none;"></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _LAZY_LOADING_WRAP">
# <div class="sa_item_inner">
# <div class="sa_item_flex">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="alist" data-gdid="880000AC_000000000000000002184917" data-imp-url="https://n.news.naver.com/mnews/article/138/0002184917" data-rank="12" href="https://n.news.naver.com/mnews/article/138/0002184917">
# <img alt="우체국, 실손보험금 청구 쉬워진다…간소화 서비스 제공" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/138/2024/10/23/2184917.jpg?type=nf220_150" height="75" onerror="this.outerHTML='&lt;span class=&quot;noimage&quot;&gt;&lt;/span&gt;'" style="display: none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title _NLOG_IMPRESSION" data-clk="alist" data-gdid="880000AC_000000000000000002184917" data-imp-url="https://n.news.naver.com/mnews/article/138/0002184917" data-rank="12" href="https://n.news.naver.com/mnews/article/138/0002184917">
# <strong class="sa_text_strong">우체국, 실손보험금 청구 쉬워진다…간소화 서비스 제공</strong>
# </a>
# <div class="sa_text_lede">오는 25일부터 질병과 상해 등으로 병원 진료를 받은 뒤 진료비 관련 서류 발급없이 우체국 실손보험금을 간편하게 청구할 수 있게 된다. 과학기술정보통신부 우정사업본부(본부장 조해근)는 '우체국예금·보험에 관한 법률'</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">디지털데일리</div>
# <div class="sa_text_datetime is_recent">
# <b>35분전</b>
# </div>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news138,0002184917" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/138/0002184917" style="display: none;"></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="section_article _TEMPLATE" data-template-id="SECTION_ARTICLE_LIST_FOR_LATEST">
# <ul class="sa_list">
# <li class="sa_item _LAZY_LOADING_WRAP">
# <div class="sa_item_inner">
# <div class="sa_item_flex">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="alist" data-gdid="880000D8_000000000000000015000934" data-imp-url="https://n.news.naver.com/mnews/article/001/0015000934" data-rank="13" href="https://n.news.naver.com/mnews/article/001/0015000934">
# <img alt='노벨물리학상 아스페 교수 "스타트업 기반 양자 경제 만들어야"' class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/001/2024/10/23/15000934.jpg?type=nf220_150" height="75" onerror="this.outerHTML='&lt;span class=&quot;noimage&quot;&gt;&lt;/span&gt;'" style="display: none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title _NLOG_IMPRESSION" data-clk="alist" data-gdid="880000D8_000000000000000015000934" data-imp-url="https://n.news.naver.com/mnews/article/001/0015000934" data-rank="13" href="https://n.news.naver.com/mnews/article/001/0015000934">
# <strong class="sa_text_strong">노벨물리학상 아스페 교수 "스타트업 기반 양자 경제 만들어야"</strong>
# </a>
# <div class="sa_text_lede">2019년 프랑스 양자컴퓨터 기업 파스칼 설립…2022년 '양자 얽힘' 입증해 노벨상 수상 "국내 기업 5~6곳과 협력 논의…한국에 양자 개발 아시아 허브 구축" "파스칼과 같은 양자 관련 스타트업이 한국에 많지 않</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">연합뉴스</div>
# <div class="sa_text_datetime is_recent">
# <b>35분전</b>
# </div>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news001,0015000934" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/001/0015000934" style="display: none;"></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _LAZY_LOADING_WRAP">
# <div class="sa_item_inner">
# <div class="sa_item_flex">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="alist" data-gdid="88000127_000000000000000012858162" data-imp-url="https://n.news.naver.com/mnews/article/003/0012858162" data-rank="14" href="https://n.news.naver.com/mnews/article/003/0012858162">
# <img alt="과학기술유공자 故 김재관·박상대 박사, 현충원에 안장된다" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/003/2024/10/23/12858162.jpg?type=nf220_150" height="75" onerror="this.outerHTML='&lt;span class=&quot;noimage&quot;&gt;&lt;/span&gt;'" style="display: none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title _NLOG_IMPRESSION" data-clk="alist" data-gdid="88000127_000000000000000012858162" data-imp-url="https://n.news.naver.com/mnews/article/003/0012858162" data-rank="14" href="https://n.news.naver.com/mnews/article/003/0012858162">
# <strong class="sa_text_strong">과학기술유공자 故 김재관·박상대 박사, 현충원에 안장된다</strong>
# </a>
# <div class="sa_text_lede">우리나라의 중공업 발전을 이끌고, 한국 생명과학의 태동과 세계화에 앞장선 2명의 과학기술유공자가 국립묘지로 안장된다. 과학기술정보통신부는 지난 10월10일 진행된 국가보훈부 제19회 국립묘지 안장대상 심의위원회 심의</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">뉴시스</div>
# <div class="sa_text_datetime is_recent">
# <b>35분전</b>
# </div>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news003,0012858162" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/003/0012858162" style="display: none;"></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _LAZY_LOADING_WRAP">
# <div class="sa_item_inner">
# <div class="sa_item_flex">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="alist" data-gdid="88000127_000000000000000012858156" data-imp-url="https://n.news.naver.com/mnews/article/003/0012858156" data-rank="15" href="https://n.news.naver.com/mnews/article/003/0012858156">
# <img alt="내달 25일부터 '우체국 실손보험금 청구 간소화' 서비스" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/003/2024/10/23/12858156.jpg?type=nf220_150" height="75" onerror="this.outerHTML='&lt;span class=&quot;noimage&quot;&gt;&lt;/span&gt;'" style="display: none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title _NLOG_IMPRESSION" data-clk="alist" data-gdid="88000127_000000000000000012858156" data-imp-url="https://n.news.naver.com/mnews/article/003/0012858156" data-rank="15" href="https://n.news.naver.com/mnews/article/003/0012858156">
# <strong class="sa_text_strong">내달 25일부터 '우체국 실손보험금 청구 간소화' 서비스</strong>
# </a>
# <div class="sa_text_lede">진료비 관련 서류 발급없이 우체국 실손보험금을 간편하게 청구할 수 있게 된다. 과학기술정보통신부 우정사업본부는 '우체국예금·보험에 관한 법률' 개정안 시행으로 오는 25일부터 민영보험사와 동시에 우체국보험 가입자도 </div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">뉴시스</div>
# <div class="sa_text_datetime is_recent">
# <b>35분전</b>
# </div>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news003,0012858156" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/003/0012858156" style="display: none;"></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _LAZY_LOADING_WRAP">
# <div class="sa_item_inner">
# <div class="sa_item_flex">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="alist" data-gdid="880000C2_000000000000000005104333" data-imp-url="https://n.news.naver.com/mnews/article/008/0005104333" data-rank="16" href="https://n.news.naver.com/mnews/article/008/0005104333">
# <img alt="우체국보험도 25일부터 '실손24' 가능" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/008/2024/10/23/5104333.jpg?type=nf220_150" height="75" onerror="this.outerHTML='&lt;span class=&quot;noimage&quot;&gt;&lt;/span&gt;'" style="display: none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title _NLOG_IMPRESSION" data-clk="alist" data-gdid="880000C2_000000000000000005104333" data-imp-url="https://n.news.naver.com/mnews/article/008/0005104333" data-rank="16" href="https://n.news.naver.com/mnews/article/008/0005104333">
# <strong class="sa_text_strong">우체국보험도 25일부터 '실손24' 가능</strong>
# </a>
# <div class="sa_text_lede">오는 25일부터 우체국보험 가입자도 '실손24' 모바일앱·웹사이트로 종이 증빙서류 없이 실손보험금을 청구할 수 있게 된다. 우정사업본부는 개정 우체국예금보험법 시행에 따라 오는 25일 실손보험금 청구 간소화 서비스를</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">머니투데이</div>
# <div class="sa_text_datetime is_recent">
# <b>35분전</b>
# </div>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news008,0005104333" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/008/0005104333" style="display: none;"></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _LAZY_LOADING_WRAP">
# <div class="sa_item_inner">
# <div class="sa_item_flex">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="alist" data-gdid="880000C2_000000000000000005104331" data-imp-url="https://n.news.naver.com/mnews/article/008/0005104331" data-rank="17" href="https://n.news.naver.com/mnews/article/008/0005104331">
# <img alt="韓 과학기술 기반 닦은 과학자 2人, 국립묘지 안장된다" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/008/2024/10/23/5104331.jpg?type=nf220_150" height="75" onerror="this.outerHTML='&lt;span class=&quot;noimage&quot;&gt;&lt;/span&gt;'" style="display: none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# <a class="sa_text_title _NLOG_IMPRESSION" data-clk="alist" data-gdid="880000C2_000000000000000005104331" data-imp-url="https://n.news.naver.com/mnews/article/008/0005104331" data-rank="17" href="https://n.news.naver.com/mnews/article/008/0005104331">
# <strong class="sa_text_strong">韓 과학기술 기반 닦은 과학자 2人, 국립묘지 안장된다</strong>
# </a>
# <div class="sa_text_lede">과학기술유공자인 고(故) 김재관 한국표준과학연구원(표준연) 초대 원장과 고(故) 박상대 서울대 명예교수가 국립묘지에 안장된다. 과학기술정보통신부(이하 과기정통부)는 지난 10월 열린 국가보훈부 제19회 국립묘지 안장</div>
# <div class="sa_text_info">
# <div class="sa_text_info_left">
# <div class="sa_text_press">머니투데이</div>
# <div class="sa_text_datetime is_recent">
# <b>35분전</b>
# </div>
# </div>
# <div class="sa_text_info_right">
# <a class="sa_text_cmt _COMMENT_COUNT_LIST" data-object-id="news008,0005104331" data-ticket="news" data-zero-allow="false" href="https://n.news.naver.com/mnews/article/comment/008/0005104331" style="display: none;"></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="sa_item _LAZY_LOADING_WRAP">
# <div class="sa_item_inner">
# <div class="sa_item_flex">
# <div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="sa_thumb_inner">
# <a class="sa_thumb_link _NLOG_IMPRESSION" data-clk="alist" data-gdid="08138263_000000000000000007862289" data-imp-url="https://n.news.naver.com/mnews/article/421/0007862289" data-rank="18" href="https://n.news.naver.com/mnews/article/421/0007862289">
# <img alt="카카오 새 AI '카나나'…사람처럼 보고 들으며 일상 돕는다" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/origin/421/2024/10/23/7862289.jpg?type=nf220_150" height="75" onerror="this.outerHTML='&lt;span class=&quot;noimage&quot;&gt;&lt;/span&gt;'" style="display: none;" width="110"/>
# </a>
# </div>
# </div>
# <div class="sa_text">
# ...
# <img alt="네이버 메인에서 바로 보는 언론사 편집뉴스 지금 바로 구독해보세요!" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://imgnews.pstatic.net/image/upload/item/2018/11/27/175236270_PC_%25BF%25EC%25C3%25F8%25B9%25E8%25B3%25CA_%25B1%25B8%25B5%25B6%25C8%25B0%25BC%25BA%25C8%25AD.png" height="80" style="display: none;" width="300"/>
# <div class="blind">
# <strong>네이버 메인에서 바로 보는 언론사 편집뉴스 지금 바로 구독해보세요!</strong>
# <p></p>
# </div>
# </a>
# </div>
# </div>
# <div class="col2_banner mobile_hidden is_hidden _LAZY_LOADING_WRAP" data-grid-template-column-aside="true">
# <div class="col2_banner_inner _LAZY_LOADING_ERROR_HIDE">
# <a class="col2_banner_link" data-clk="asidebanner2" href="https://media.naver.com/algorithm">
# <img alt="알고리즘 안내" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://imgnews.pstatic.net/image/upload/item/2023/07/06/183901500_banner_AI.png" height="80" style="display: none;" width="300"/>
# <div class="blind">
# <strong>알고리즘 안내</strong>
# <p></p>
# </div>
# </a>
# </div>
# </div>
# <div class="col2_banner mobile_hidden is_hidden _LAZY_LOADING_WRAP" data-grid-template-column-aside="true">
# <div class="col2_banner_inner _LAZY_LOADING_ERROR_HIDE">
# <a class="col2_banner_link" data-clk="asidebanner3" href="https://news.naver.com/main/ombudsman/guidecenter.naver?mid=omb">
# <img alt="뉴스 기사와 댓글로 인한 문제 발생 시 24시간 센터로 접수해주세요" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://imgnews.pstatic.net/image/upload/item/2023/06/23/195439840_banner_24hours.png" height="80" style="display: none;" width="300"/>
# <div class="blind">
# <strong>뉴스 기사와 댓글로 인한 문제 발생 시 24시간 센터로 접수해주세요</strong>
# <p></p>
# </div>
# </a>
# </div>
# </div>
# <div class="rankingnews as_type_flat mobile_hidden is_hidden _FLICKING_WRAP _OFFICE_RANKING_ALL _PERSIST_META _TEMPLATE" data-aggregation-end="" data-aggregation-start="" data-count="1" data-flicking-disable="true" data-flicking-init-tab-index="" data-flicking-nclk="true" data-grid-template-column-aside="true" data-nclk-prefix="rig" data-persist="6_officeRankingAll" data-persist-origin-content="true" data-template-id="SERVICE_INFORMATION_NEWS">
# <div class="ra_head">
# <strong class="ra_title"><em class="ra_highlight"></em> 서비스 안내</strong>
# <a class="media_more" data-clk="rig.more" href="https://news.naver.com/main/ombudsman/index.naver"><span class="blind">더보기</span></a>
# </div>
# <div class="ra_area">
# <div class="flick" style="height:90px;">
# <div class="flick-container _FLICKING" style="height:90px; opacity:0;">
# <div class="flick-panel" data-index="0" data-subtab-count="1">
# <ul class="ranking_list _FLICKING_CONTENT" data-index="0" style="margin-top: 0;">
# <li class="rl_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <div class="rl_link_end">
# <div class="rl_content">
# <p class="rl_txt">고침 기사 모음</p>
# </div>
# <a class="rl_coverlink" data-clk="rig.text" href="https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb">
# <span class="blind">더보기</span>
# </a>
# </div>
# </li>
# <li class="rl_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <div class="rl_link_end">
# <div class="rl_content">
# <p class="rl_txt">정정·반론·추후 보도 기사 모음</p>
# </div>
# <a class="rl_coverlink" data-clk="rig.text" href="https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb">
# <span class="blind">더보기</span>
# </a>
# </div>
# </li>
# <li class="rl_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <div class="rl_link_end">
# <div class="rl_content">
# <p class="rl_txt">불공정 선거 보도 기사 모음</p>
# </div>
# <a class="rl_coverlink" data-clk="rig.text" href="https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb">
# <span class="blind">더보기</span>
# </a>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="_MY_CHANNEL_OFFICE_WRAP pc_hidden" data-grid-template-column-aside="true">
# </div></div>
# <div class="outside_area _OUTSIDE_AREA">
# <div class="outside_area_inner _GRID_TEMPLATE_COLUMN_ASIDE _OUTSIDE_AREA_INNER"></div>
# </div>
# <aside class="main_aside _MAIN_ASIDE">
# <div class="main_aside_inner _MAIN_ASIDE_INNER">
# <h3 class="blind">구독</h3>
# <script class="_LAZY_LOADING_IFRAME" type="x-tmpl-mustache">
# 			<iframe class="_aside _GRID_TEMPLATE_ASIDE_IFRAME" src="https://news.naver.com/aside" data-allow-domain="https://news.naver.com" style="visibility: hidden;" frameborder="no" scrolling="no" width="100%" title="구독 목록"></iframe>
# 			</script>
# </div>
# </aside>
# </div>
# </div>
# <div class="media_end_tts_ticker _FADE_LAYER" id="_media_end_tts_ticker" style="display: none;">
# <p class="media_end_tts_ticker_text" style="display: block;">본문 듣기를 <em class="media_end_tts_ticker_point">종료</em>하였습니다.</p>
# </div>
# <div class="tomain_ticker _TOMAIN_RECOMMAND_LAYER _FADE_LAYER" style="display: none;">이 기사를 <em class="tomain_ticker_point">추천</em>했습니다.
# </div>
# <div class="tomain_ticker _TOMAIN_CANCEL_LAYER _FADE_LAYER" style="display: none;">추천을 <em class="tomain_ticker_point">취소</em>했습니다.
# </div><hr/>
# <div class="u_ft _STICKY_FOOTER">
# <div class="u_ft_inner">
# <footer role="contentinfo">
# <p class="u_cr">
# <span class="u_ftm">
# <span class="u_cri u_cri_v1">
# <a class="u_cra _LINK" data-clk="fot.login" data-pc-url="https://nid.naver.com/nidlogin.login" data-url="https://nid.naver.com/nidlogin.login?svctype=262144" href="https://nid.naver.com/nidlogin.login?svctype=262144">로그인</a>
# </span>
# <span class="u_cri u_cri_v1">
# <a class="u_cra _LINK" data-clk="fot.serviceall" data-pc-url="https://www.naver.com/more.html" data-url="https://m.naver.com/services.html?f=svc.news" href="https://m.naver.com/services.html?f=svc.news">전체서비스</a>
# </span>
# </span>
# <span class="u_ftm">
# <span class="u_cri u_cri_v1">
# <a class="u_cra _LINK" data-clk="fot.guide" data-pc-url="https://news.naver.com/main/ombudsman/index.naver" data-url="https://m.news.naver.com/ombudsman/index" href="https://m.news.naver.com/ombudsman/index">서비스안내</a>
# </span>
# <span class="u_cri u_cri_v1">
# <a class="u_cra" data-clk="fot.report" href="https://help.naver.com/alias/news/news_001.naver">오류신고</a>
# </span>
# <span class="u_cri u_cri_v1">
# <a class="u_cra" data-clk="fot.help" href="https://help.naver.com/alias/news/news_007.naver">고객센터</a>
# </span>
# </span>
# <span class="u_charge">
# <a class="u_charge_item _LINK" data-clk="fot.editor" data-pc-url="https://news.naver.com/main/ombudsman/edit.naver?mid=omb" data-url="https://m.news.naver.com/ombudsman/index?mode=rule" href="https://m.news.naver.com/ombudsman/index?mode=rule">기사배열 책임자 : 김수향</a>
# <span class="u_charge_item">청소년 보호 책임자 : 이정규</span>
# </span>
# <span class="u_copyright">
# 					이 콘텐츠의 저작권은 저작권자 또는 제공처에 있으며, 이를 무단 <br/>이용하는 경우 저작권법 등에 따라 법적 책임을 질 수 있습니다.
# 				</span>
# <span class="u_naverlogo">
# <a class="u_naverlogo_a" data-clk="fot.navercorp" href="https://www.navercorp.com">NAVER</a>
# </span>
# </p>
# </footer>
# </div>
# </div>
# <a class="r_pg_top show _MOVE_TOP" data-clk="fot.top" href="#" id="goTop" style="display:none;">맨위로</a>
# <div class="subscribe_dimmed is_hidden" id="_MY_FEED_CANCEL_MODAL" style="display:none;">
# <div class="subscribe_alert">
# <p class="subscribe_alert_p _message _MY_FFED_CANCEL_MODAL_MESSAGE">
# </p>
# <div class="subscribe_alert_btns">
# <a class="subscribe_alert_btn _CANCEL_YES_BTN _TOGGLE" data-classvalue="is_hidden" data-target="_MY_FEED_CANCEL_MODAL" href="#">예</a>
# <a class="subscribe_alert_btn _TOGGLE" data-classvalue="is_hidden" data-target="_MY_FEED_CANCEL_MODAL" href="#">아니오</a>
# </div>
# </div>
# </div>
# <script class="_MY_FEED_CANCEL_MODAL_TEMPLATE" type="x-tmpl-mustache">
# 			{{#series}}
# 			<span class="subscribe_alert_p_ellipsis">{{value}}</span><br>연재 구독을 취소하시겠습니까? <span class="subscribe_alert_p_dsc">해당 연재는 <em>구독</em>에서 제외됩니다.</span>
# 			{{/series}}
# 			{{#journalist}}
# 			{{value}} 기자의 기사<br> 구독을 취소하시겠습니까? <span class="subscribe_alert_p_dsc"><em>구독</em>에서 해당 기자의 기사가 제외됩니다.</span>
# 			{{/journalist}}
# </script>
# <div class="modal is_hidden" id="_MODAL_LAYER_FOR_NOTIFICATION"></div>
# <div class="modal is_hidden" id="_MODAL_LAYER_FOR_NOTIFICATION_ALL"></div>
# <div class="modal is_hidden" id="_MODAL_LAYER_FOR_NOTIFICATION_OS"></div>
# <script class="_MODAL_LAYER_TEMPLATE_FOR_NOTIFICATION" type="x-tmpl-mustache">
# <div class="m_dimmed"></div>
# <div class="m_notification is_single">
# 	<strong class="mn_ok">구독완료</strong>
# 	{{#officeInfos}}
# 	<div class="mn_text">
# 		<h4 class="mn_h">{{officeName}} 뉴스를 <br> <span class="m_em">알림</span>으로 받아 보시겠습니까?</h4>
# 		<p class="mn_p">언론사의 주요 콘텐츠를 <br> 네이버에서 빠르게 확인할 수 있습니다.</p>
# 	</div>
# 	{{/officeInfos}}
# 	<div class="mn_btns">
# 		<button type="button" class="mn_btn _MODAL_LAYER_NEGATIVE" data-clk="{{nclk}}no">닫기</button>
# 		<button type="button" class="mn_btn as_em _MODAL_LAYER_POSITIVE" data-clk="{{nclk}}yes">알림받기</button>
# 	</div>
# </div>
# </script>
# <script class="_MODAL_LAYER_TEMPLATE_FOR_NOTIFICATION_ALL" type="x-tmpl-mustache">
# <div class="m_dimmed"></div>
# <div class="m_notification">
# 	<strong class="mn_ok">구독완료</strong>
# 	<div class="mn_text">
# 		<h4 class="mn_h">언론사의 주요 뉴스를 <br> <span class="m_em">알림</span>으로 받아 보시겠습니까?</h4>
# 		<ul class="mn_list">
# 			{{#officeInfos}}
# 			<li class="mn_item">
# 				<div class="mn_head">
# 					<div class="mn_img">
# 						<img src="{{logo}}" alt="" onerror="this.outerHTML='<span class=&quot;no_image&quot;></span>'">
# 					</div>
# 					<div class="mn_name">{{officeName}}</div>
# 				</div>
# 				<div class="mn_body">
# 					<button type="button" class="mn_noti _ALL_OFFICES_NOTIFICATION_ITEM" data-oid="{{officeId}}" data-clk-add="notchnon" data-clk-remove="notchnoff">알림받기 사용함</button>
# 				</div>
# 			</li>
# 			{{/officeInfos}}
# 		</ul>
# 	</div>
# 	<div class="mn_btns">
# 		<button type="button" class="mn_btn _MODAL_LAYER_NEGATIVE" data-clk="{{nclk}}no">닫기</button>
# 		<button type="button" class="mn_btn as_em _MODAL_LAYER_POSITIVE _CHANNEL_BANNER_ITEM_NOTICE_COMPLETE" data-clk="{{nclk}}yes">완료</button>
# 	</div>
# </div>
# </script>
# <script class="_MODAL_LAYER_TEMPLATE_FOR_NOTIFICATION_OS" type="x-tmpl-mustache">
# <div class="m_dimmed"></div>
# <div class="napp_notify_notice">
# 	<div class="napp_notify_info_area">
# 		<strong class="napp_notify_title">네이버 앱 푸시알림이 꺼져있어요.</strong>
# 		<div class="napp_notify_desc_box">
# 			<p class="napp_notify_desc1">네이버 앱 알림켜기 &gt; 알림탭 &gt; 알림허용</p>
# 			<p class="napp_notify_desc2">버튼을 눌러 앱 알림 설정을 켜주세요.</p>
# 		</div>
# 	</div>
# 	<div class="napp_notify_button_area">
# 		<button type="button" class="napp_notify_btn _MODAL_LAYER_NEGATIVE" data-clk="{{nclk}}.osnotoff">닫기</button>
# 		<button type="button" class="napp_notify_btn highlight _MODAL_LAYER_POSITIVE _NAPP_NOTIFY_COMPLETE" data-clk="{{nclk}}.osnoton">네이버 앱 알림 켜기</button>
# 	</div>
# </div>
# </div>
# </script>
# <div id="_MODAL_COMMENT_FOLLOW_TUTORIAL" style="display: none;"></div>
# <script class="_MODAL_COMMENT_FOLLOW_TUTORIAL_TEMPLATE" type="x-tmpl-mustache">
# <div class="comment_follow_tutorial" role="dialog" aria-modal="true">
# 	<div class="comment_follow_tutorial_layer">
# 		<div class="comment_follow_tutorial_layer_dimmed"></div>
# 		<div class="comment_follow_tutorial_layer_container">
# 			<div class="comment_follow_tutorial_layer_content">
# 				<div class="comment_follow_tutorial_layer_item">
# 					<p class="{{className}}">{{text}}</p>
# 					<i class="comment_follow_tutorial_layer_closeicon"></i>
# 					<button type="button" class="comment_follow_tutorial_layer_close _MODAL_COMMENT_FOLLOW_TUTORIAL_CLOSE" data-clk="{{nclkPrefix}}tutclose">닫기</button>
# 				</div>
# 			</div>
# 		</div>
# 	</div>
# </div>
# </script>
# <div class="ticker" id="_TICKER_LAYER_FOR_NOTIFICATION" style="display: none;"></div>
# <script class="_TICKER_LAYER_TEMPLATE_FOR_NOTIFICATION" type="x-tmpl-mustache">
# {{#officeInfos}}
# <p class="t_inner"><em class="t_point">{{officeName}}</em> 언론사 알림이 설정되었습니다.</p>
# {{/officeInfos}}
# </script>
# <script src="https://static-nnews.pstatic.net/js/min/20241018a/library.min.js"></script>
# <script src="https://static-nnews.pstatic.net/js/min/20241018a/read.min.js"></script>
# <script>
# 	window.ntm = window.ntm || [];
# 	var ntmOption = {};
#
# 	if (ntmOption) {
#
# 		var section = {};
# 		var redirectSection = {"id":"105","name":"IT"};
#
# 		ntmOption["channelId"] = article.officeId;
#
# 		// 기타 또는 주요 섹션 이름
# 		var nilSendSectionName = "기타";
# 		var nilSendSectionId = "";
# 		if (/100|101|102|103|104|105|106|107/.test(section.id)) {
# 			nilSendSectionName = section.name;
# 			nilSendSectionId = section.id;
# 		}
#
# 		// 기사 타입
# 		var htArticleTypeName = { "0": "text", "1": "photo", "2": "tv" };
# 		var articleTypeName = htArticleTypeName[article.type] || "";
#
# 		ntmOption["hitType"] = "cv";
# 		ntmOption["eventCategory"] = "post_view";
# 		ntmOption["uri"] = "";
# 		ntmOption["gdid"] = article.gdid;
# 		ntmOption["dimension1"] = encodeURIComponent(nilSendSectionName);
# 		ntmOption["dimension4"] = articleTypeName;
# 		ntmOption["optional2"] = nilSendSectionId;
#
# 		var journalistIdList = [];
#
# 		// 기자 목록
# 		$("._JOURNALIST_CARD ._JOURNALIST_ID").each(function (index, object) {
# 			var $this = $(object);
# 			var journalistId = $this.attr("data-journalistId");
#
# 			if (journalistId && journalistIdList.indexOf(journalistId) === -1) {
# 				journalistIdList.push(journalistId);
# 			}
# 		});
#
# 		if (journalistIdList.length > 0) {
# 			ntmOption["dimension3"] = journalistIdList.join("___");
# 		}
#
# 		if (location.href.match(/ntype=RANKING/)) {
# 			ntmOption["dimension5"] = "y";
# 		}
#
# 		if (service.sports || service.newsType) {
# 			ntmOption["dimension2"] = article.sectionInfo.secondSection + "." + article.sectionInfo.thirdSection;
# 		}
#
# 		var seriesComponentId = $("._VALID_SERIES").attr("data-component-id");
# 		ntmOption["dimension6"] = seriesComponentId;
#
# 		var issueComponentId = $("._ISSUE_ARTICLE_INFO").attr("data-component-id");
# 		ntmOption["dimension8"] = issueComponentId;
#
# 		if (/[?|&]type=breakingnews(&|$)/.test(location.href) === true) {
# 			if (/(m\.naver\.com)|(media\.naver\.com)|(news\.naver\.com\/?$)|(www\.naver\.com)/.test(document.referrer) === true) {
# 				ntmOption["dimension7"] = "breaking";
# 			}
# 		}
#
# 		var ntmLeaveOption = $.extend({}, ntmOption);
# 		ntmLeaveOption["hitType"] = "event";
# 		ntmLeaveOption["eventCategory"] = "action";
# 		ntmLeaveOption["eventAction"] = "leave";
#
# 		if (/\/article\/comment\//.test(location.href) == false && $("#contents").length > 0) {
# 			if (window.addEventListener) {
# 				window.addEventListener("load", function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmOption
# 					});
# 				}, false);
# 				window.addEventListener("onpagehide" in window ? "pagehide" : "beforeunload", function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmLeaveOption
# 					});
# 				}, false);
# 			} else if (window.attachEvent) {
# 				window.attachEvent("onload", function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmOption
# 					});
# 				});
# 				window.attachEvent("onpagehide" in window ? "onpagehide" : "onbeforeunload", function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmLeaveOption
# 					});
# 				});
# 			} else {
# 				var onUnloadEventName = "onpagehide" in window ? "onpagehide" : "onbeforeunload";
# 				var fnOnUnload = window[onUnloadEventName];
# 				window[onUnloadEventName] = function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmLeaveOption
# 					});
# 					if (fnOnUnload) {
# 						fnOnUnload();
# 					}
# 				};
#
# 				var fnOnload = window.onload;
# 				window.onload = function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmOption
# 					});
# 					if (fnOnload) {
# 						fnOnload();
# 					}
# 				};
# 			}
# 		}
# 	}
# </script>
# </div>
# <script>
# 			var eventType = "onpageshow" in window ? "pageshow" : "load";
# 			$(window).on(eventType, function() {
# 				window.ntm = window.ntm || [];
#
# 				var pageviewInfo = {
# 					event: "nLogPageViewService"
# 				};
#
# 				pageviewInfo.nLogPageviewSti = "news";
#
# 				window.ntm.push(pageviewInfo);
#
# 				// ma 로그 전송
# 				var data = {
# 					"service": "news",
# 					"baseInfo": {
# 						"category": "섹션홈"
# 					},
# 					"extraInfo": {
# 						"sectionId": "105"
# 					}
# 				};
#
# 				if (typeof ma !== "undefined") {
# 					ma.init({
# 						api: "https://ma.news.naver.com/l",
# 						data: data
# 					});
# 				}
#
# 				if (window.matchMedia("(prefers-color-scheme)").media === "not all") {
# 					$("html").removeClass("DARK_THEME");
# 				}
# 			});
# 		</script>
# </body>
# </html>

# %%
# ! pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.3-cp312-cp312-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\human\.conda\envs\human-da-env\lib\site-packages (from wordcloud) (2.1.2)
# Requirement already satisfied: pillow in c:\users\human\.conda\envs\human-da-env\lib\site-packages (from wordcloud) (11.0.0)
# Requirement already satisfied: matplotlib in c:\users\human\.conda\envs\human-da-env\lib\site-packages (from wordcloud) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\human\.conda\envs\human-da-env\lib\site-packages (from matplotlib->wordcloud) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\human\.conda\envs\human-da-env\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\human\.conda\envs\human-da-env\lib\site-packages (from matplotlib->wordcloud) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\human\.conda\envs\human-da-env\lib\site-packages (from matplotlib->wordcloud) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\human\.conda\envs\human-da-env\lib\site-packages (from matplotlib->wordcloud) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\human\.conda\envs\human-da-env\lib\site-packages (from matplotlib->wordcloud) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\human\.conda\envs\human-da-env\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\human\.conda\envs\human-da-env\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Downloading wordcloud-1.9.3-cp312-cp312-win_amd64.whl (301 kB)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.3

# %%
a_list = soup.select(".sa_list .sa_item .sa_text a")
len(a_list)
# Out:
# 72

# %%
for a in a_list:
    print(a.text)
# Out:
# 군수자원 관리 효율화…삼성SDS, 공군과 디지털전환 MOU
#
#
#
# 카카오-엔비디아와 맞손…"카나나 알파팀과 AI 모델 만든다"
#
#
#
# 지구 생명체, 외계서 왔나…운석 충돌 생명 기원 근거 나와
#
#
#
# [유통 픽] 스타벅스, 다음 달부터 겨울 e-프리퀀시 시작 外
#
#
#
# 오픈AI, 美 민주당 백악관 출신 인사 잇단 영입
#
#
#
# "재사용 힘든 차세대 발사체, 메탄 엔진 연구에 우주청 나서야"
#
#
#
# 삼성 TV “배경화면이 말만하면 원하는 대로”...2024년형 모델에 적용
#
#
#
# "엔비디아, 태국 투자계획 발표할 것…12월 젠슨 황 방문"
#
#
#
# 퀄컴·구글, 생성형AI 기반 디지털 콕핏 개발 나섰다
#
#
#
# 우체국 실손보험금 청구 쉬워졌다…‘실손보험금 청구 간소화 서비스’ 시행
#
#
#
# 대한민국 과학기술유공자 2인, 국립묘지 안장 결정
#
#
#
# 우체국, 실손보험금 청구 쉬워진다…간소화 서비스 제공
#
#
#
# 노벨물리학상 아스페 교수 "스타트업 기반 양자 경제 만들어야"
#
#
#
# 과학기술유공자 故 김재관·박상대 박사, 현충원에 안장된다
#
#
#
# 내달 25일부터 '우체국 실손보험금 청구 간소화' 서비스
#
#
#
# 우체국보험도 25일부터 '실손24' 가능
#
#
#
# 韓 과학기술 기반 닦은 과학자 2人, 국립묘지 안장된다
#
#
#
# 카카오 새 AI '카나나'…사람처럼 보고 들으며 일상 돕는다
#
#
#
# 퀄컴, 차세대 오토모티브 플랫폼 공개 “AI성능 12배 향상”
#
#
#
# 4일 연속 하락한 테슬라, 실적 발표로 반등 모멘텀 잡을까?
#
#
#
# 신성이엔지, 'SEDEX 2024'서 클린룸 기술력 공개
#
#
#
# SK하이닉스, 최준기 부사장 은탑산업훈장 수훈...“HBM 생산 확대 기여”
#
#
#
# 사탕 담는 휴머노이드 ‘앨리스’… 최첨단 로봇 한자리에
#
#
#
# 엔비디아 젠슨 황·릴라이언스 무케시 암바니, 인도서 ‘AI 비전’ 대담
#
#
#
# 경쟁 치열한 '이산화탄소 미니발전소', 국내 개발 완료 눈앞
#
#
#
# 원주시, 발송 문자메시지에 '브랜드 프로필 서비스' 적용
#
#
#
# 한컴, 일본 최대 IT 전시회 참가…"현지 진출 본격화"
#
#
#
# "일상 속 이동, 더 ‘똑똑하게’"...카카오모빌리티, 기술 비전 공유
#
#
#
# 삼성SDS·공군본부, 공군 군수혁신 위한 업무협약
#
#
#
# 외로움, 치매 위험 31% 높인다…인지 장애와도 관련
#
#
#
# 삼성SDS·공군본부, 군수혁신을 위해 업무협약 체결
#
#
#
# 방심위 차단 의결에 나무위키, 사생활 정보 결국 삭제
#
#
#
# LX세미콘, 디스플레이 IC·차량용 반도체 공개 [반도체 대전 2024]
#
#
#
# 카카오, '카나나' AI 모델 10종 공개…"비용 효율적인 LLM"
#
#
#
# 삼성SDS, 공군 군수관리시스템에 AI 적용
#
#
#
# 한싹, 국방 특화 AI 소요 예측 모델 개발 착수

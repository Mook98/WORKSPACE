# %%
import os
import sys
import urllib.request #웹 요청을 전송하고 응답을 수신하는 모듈 (브라우저 역할)

# 서버로 전송하는 데이터
client_id = "l5MmBDqXFev6LQtN_8q9"
client_secret = "DzmQdGg9hI"
encText = urllib.parse.quote("소년이온다")

# 요청 url + get 방식 전송 데이터 구성
url = "https://openapi.naver.com/v1/search/book.json?query={0}&display={1}".format(encText, 50) # JSON 결과
request = urllib.request.Request(url)

# header에 전송 데이터 저장
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret) 

response = urllib.request.urlopen(request) # 요청 보내기 + 응답 수신

rescode = response.getcode() # 응답코드 읽기
if(rescode==200): # 정상 응답이라면
    response_body = response.read() # 응답 데이터 읽기
    print(response_body.decode('utf-8')) # binary 데이터를 utf-8 text 데이터로 변환
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Wed, 23 Oct 2024 09:02:18 +0900",
# 	"total":10,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"소년이 온다 (한강 소설 l 2024년 노벨문학상 수상작가)",
# 			"link":"https:\/\/search.shopping.naver.com\/book\/catalog\/32491401626",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_3249140\/32491401626.20231004072435.jpg",
# 			"author":"한강",
# 			"discount":"13500",
# 			"publisher":"창비",
# 			"pubdate":"20140519",
# 			"isbn":"9788936434120",
# ...

# %%
urllib.parse.quote("소년이 온다")
# Out:
# '%EC%86%8C%EB%85%84%EC%9D%B4%20%EC%98%A8%EB%8B%A4'

# %%
text_response = response_body.decode('utf-8')

# %%
type(text_response)
# Out:
# str

# %%
# json str -> dict
import json

dict_response = json.loads(text_response)

print(type(dict_response))
#print(dict_response)

print(type(dict_response['items']))
for idx, item in enumerate(dict_response['items']):
    # print(type(item))
    print("{0}. {1}".format(idx + 1, item['title']))
# Out:
# <class 'dict'>
# <class 'list'>
# 1. 소년이 온다 (한강 소설 l 2024년 노벨문학상 수상작가)
# 2. 소년이 온다 1(큰글자도서) (한강 소설ㅣ2024년 노벨문학상 수상작가)
# 3. 소년이 온다 2(큰글자도서) (2024년 노벨문학상 수상작가)
# 4. Human Acts 한강 작가『소년이 온다』 영문판 (영국판) (소년이 온다)
# 5. Human Acts  한강 작가『소년이 온다』 영문판 (미국판) (소년이 온다)
# 6. 소년이 온다(특별한정판) (한강 소설ㅣ2024년 노벨문학상 수상작가)
# 7. 少年來了 - 소년이 온다 (2024 노벨문학상 수상작가 한강『소년이 온다』대만판)
# 8. Celui Qui Revient (한강 - 소년이 온다 프랑스어)
# 9. Atti umani (2024 노벨문학상 수상작가 한강 『소년이 온다』 이탈리아어판)
# 10. Human Acts 한강 작가『소년이 온다』 영문판 (영국판)

# %%
# titles = []
# for idx, item in enumerate(dict_response['items']):
#     titles.append(item['title'])

titles = [item['title'] for item in dict_response['items']]

print(titles)
# Out:
# ['소년이 온다 (한강 소설 l 2024년 노벨문학상 수상작가)', '소년이 온다 1(큰글자도서) (한강 소설ㅣ2024년 노벨문학상 수상작가)', '소년이 온다 2(큰글자도서) (2024년 노벨문학상 수상작가)', 'Human Acts 한강 작가『소년이 온다』 영문판 (영국판) (소년이 온다)', 'Human Acts  한강 작가『소년이 온다』 영문판 (미국판) (소년이 온다)', '소년이 온다(특별한정판) (한강 소설ㅣ2024년 노벨문학상 수상작가)', '少年來了 - 소년이 온다 (2024 노벨문학상 수상작가 한강『소년이 온다』대만판)', 'Celui Qui Revient (한강 - 소년이 온다 프랑스어)', 'Atti umani (2024 노벨문학상 수상작가 한강 『소년이 온다』 이탈리아어판)', 'Human Acts 한강 작가『소년이 온다』 영문판 (영국판)']

# %%
! pip install pandas

# %%
import pandas as pd
df_response = pd.DataFrame(dict_response['items'])
print(df_response)
type(df_response)
# Out:
#                                              title  \
# 0                소년이 온다 (한강 소설 l 2024년 노벨문학상 수상작가)
# 1         소년이 온다 1(큰글자도서) (한강 소설ㅣ2024년 노벨문학상 수상작가)
# 2               소년이 온다 2(큰글자도서) (2024년 노벨문학상 수상작가)
# 3      Human Acts 한강 작가『소년이 온다』 영문판 (영국판) (소년이 온다)
# 4     Human Acts  한강 작가『소년이 온다』 영문판 (미국판) (소년이 온다)
# 5           소년이 온다(특별한정판) (한강 소설ㅣ2024년 노벨문학상 수상작가)
# 6    少年來了 - 소년이 온다 (2024 노벨문학상 수상작가 한강『소년이 온다』대만판)
# 7             Celui Qui Revient (한강 - 소년이 온다 프랑스어)
# 8  Atti umani (2024 노벨문학상 수상작가 한강 『소년이 온다』 이탈리아어판)
# 9               Human Acts 한강 작가『소년이 온다』 영문판 (영국판)
#
#                                                 link  \
# 0  https://search.shopping.naver.com/book/catalog...
# 1  https://search.shopping.naver.com/book/catalog...
# 2  https://search.shopping.naver.com/book/catalog...
# 3  https://search.shopping.naver.com/book/catalog...
# 4  https://search.shopping.naver.com/book/catalog...
# 5  https://search.shopping.naver.com/book/catalog...
# ...

# %%
import os
import sys
import urllib.request

encText = urllib.parse.quote("고양이")
url = "https://dapi.kakao.com/v2/search/image.json?query={0}&siz={1}".format(encText, 50)

request = urllib.request.Request(url)

api_key = "6063b30445c9aa5900ea550d5e5e0ab2"
request.add_header("Authorization", f"KakaoAK {api_key}")

response = urllib.request.urlopen(request)

rescode = response.getcode()
if rescode == 200:
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + str(rescode))
# Out:
# {"documents":[{"collection":"news","datetime":"2024-02-24T00:01:48.000+09:00","display_sitename":"중앙SUNDAY","doc_url":"http://v.media.daum.net/v/20240224000148735","height":687,"image_url":"https://t1.daumcdn.net/news/202402/24/joongangsunday/20240224000150215efvd.jpg","thumbnail_url":"https://search1.kakaocdn.net/argon/130x130_85_c/ClWMVzfq2oc","width":458},{"collection":"news","datetime":"2024-02-25T07:01:02.000+09:00","display_sitename":"아시아경제","doc_url":"http://v.media.daum.net/v/20240225070102565","height":960,"image_url":"https://t1.daumcdn.net/news/202402/25/akn/20240225070103638jeqk.jpg","thumbnail_url":"https://search2.kakaocdn.net/argon/130x130_85_c/H7TwG221oUm","width":640},{"collection":"news","datetime":"2016-05-12T10:01:01.000+09:00","display_sitename":"티브이데일리","doc_url":"http://v.media.daum.net/v/20160512100103791","height":550,"image_url":"http://t1.daumcdn.net/news/201605/12/tvdaily/20160512100102265bbao.jpg","thumbnail_url":"https://search1.kakaocdn.net/argon/130x13
# ...

# %%
img_response = response_body.decode('utf-8')

# %%
type(img_response)
# Out:
# str

# %%
import json

dict_response_1 = json.loads(img_response)

print(type(dict_response_1))
dict_response_1
# Out:
# <class 'dict'>
# {'documents': [{'collection': 'news',
#    'datetime': '2024-02-24T00:01:48.000+09:00',
#    'display_sitename': '중앙SUNDAY',
#    'doc_url': 'http://v.media.daum.net/v/20240224000148735',
#    'height': 687,
#    'image_url': 'https://t1.daumcdn.net/news/202402/24/joongangsunday/20240224000150215efvd.jpg',
#    'thumbnail_url': 'https://search1.kakaocdn.net/argon/130x130_85_c/ClWMVzfq2oc',
#    'width': 458},
#   {'collection': 'news',
#    'datetime': '2024-02-25T07:01:02.000+09:00',
#    'display_sitename': '아시아경제',
#    'doc_url': 'http://v.media.daum.net/v/20240225070102565',
#    'height': 960,
#    'image_url': 'https://t1.daumcdn.net/news/202402/25/akn/20240225070103638jeqk.jpg',
#    'thumbnail_url': 'https://search2.kakaocdn.net/argon/130x130_85_c/H7TwG221oUm',
#    'width': 640},
#   {'collection': 'news',
#    'datetime': '2016-05-12T10:01:01.000+09:00',
#    'display_sitename': '티브이데일리',
#    'doc_url': 'http://v.media.daum.net/v/20160512100103791',
# ...

# %%
print(type(dict_response_1['documents']))
for idx, image in enumerate(dict_response_1['documents']):
    # print(type(item))
    print("{0}. {1}".format(idx + 1, image['image_url']))
# Out:
# <class 'list'>
# 1. https://t1.daumcdn.net/news/202402/24/joongangsunday/20240224000150215efvd.jpg
# 2. https://t1.daumcdn.net/news/202402/25/akn/20240225070103638jeqk.jpg
# 3. http://t1.daumcdn.net/news/201605/12/tvdaily/20160512100102265bbao.jpg
# 4. https://t1.daumcdn.net/news/202103/26/sportskhan/20210326154226470iwqg.jpg
# 5. https://blog.kakaocdn.net/dn/bl7lDg/btsB7Q7oL8r/7H6sCuFtv0516axPWXpggk/img.jpg
# 6. https://t1.daumcdn.net/cfile/tistory/99D662505B81615310
# 7. https://t1.daumcdn.net/cfile/tistory/9978693B5C4D49A03B
# 8. https://blog.kakaocdn.net/dn/k0rZu/btsKbR5XX7S/S1SSA15yhKEmBu6KrrjW00/img.jpg
# 9. https://blog.kakaocdn.net/dn/wBkF2/btsKbJ8veMX/kIKxF9fnNQydqnElfslXO0/img.webp
# 10. https://blog.kakaocdn.net/dn/ciV3do/btsFQsb8cg0/azPjeJ2sNdvCRFCXuY7kz0/img.jpg
# 11. https://blog.kakaocdn.net/dn/zgzRq/btsmnQiANKE/OKl4JYxZI9cqTTifewqtrK/img.jpg
# 12. https://images.mypetlife.co.kr/content/uploads/2019/12/09151902/GettyImages-177033046.jpg
# ...

# %%
images = [image['image_url'] for imgae in dict_response_1['documents']]
print(images)
# Out:
# ['http://shop.daumcdn.net/shophow/p/O29356754565.jpg?ut=20241016200848', 'http://shop.daumcdn.net/shophow/p/O29356754565.jpg?ut=20241016200848', 'http://shop.daumcdn.net/shophow/p/O29356754565.jpg?ut=20241016200848', 'http://shop.daumcdn.net/shophow/p/O29356754565.jpg?ut=20241016200848', 'http://shop.daumcdn.net/shophow/p/O29356754565.jpg?ut=20241016200848', 'http://shop.daumcdn.net/shophow/p/O29356754565.jpg?ut=20241016200848', 'http://shop.daumcdn.net/shophow/p/O29356754565.jpg?ut=20241016200848', 'http://shop.daumcdn.net/shophow/p/O29356754565.jpg?ut=20241016200848', 'http://shop.daumcdn.net/shophow/p/O29356754565.jpg?ut=20241016200848', 'http://shop.daumcdn.net/shophow/p/O29356754565.jpg?ut=20241016200848', 'http://shop.daumcdn.net/shophow/p/O29356754565.jpg?ut=20241016200848', 'http://shop.daumcdn.net/shophow/p/O29356754565.jpg?ut=20241016200848', 'http://shop.daumcdn.net/shophow/p/O29356754565.jpg?ut=20241016200848', 'http://shop.daumcdn.net/shophow/p/O29356754565.jpg?ut=202410
# ...

# %%
import pandas as pd
df_response_img = pd.DataFrame(dict_response_1['documents'])
df_response_img['image_url']
# Out:
# 0     https://t1.daumcdn.net/news/202402/24/joongang...
# 1     https://t1.daumcdn.net/news/202402/25/akn/2024...
# 2     http://t1.daumcdn.net/news/201605/12/tvdaily/2...
# 3     https://t1.daumcdn.net/news/202103/26/sportskh...
# 4     https://blog.kakaocdn.net/dn/bl7lDg/btsB7Q7oL8...
#                             ...
# 75    https://blog.kakaocdn.net/dn/wNBlx/btr2D3G3oCv...
# 76    https://blog.kakaocdn.net/dn/bjMeq8/btr0yh1rZO...
# 77    http://shop.daumcdn.net/shophow/p/B5140883511....
# 78    https://blog.kakaocdn.net/dn/biZO01/btszkSUztc...
# 79    http://shop.daumcdn.net/shophow/p/O29356754565...
# Name: image_url, Length: 80, dtype: object

# %%
# ! pip install matplotlib

# %%
import matplotlib.pyplot as plt
from PIL import Image # 이미지 처리 모듈 + 클래스
from io import BytesIO # 메모리의 데이터를 파일 처럼 사용하는 도구
import requests

response = requests.get(df_response_img['image_url'][0])
if response.status_code == 200:
    image = Image.open(BytesIO(response.content))
    plt.imshow(image)
    plt.axis('off')
    plt.show()
else:
    print("error" + response.status_code)

# %%
import os
import sys
import urllib.request
api_key = "ym1IV1jj6wtrAIK%2Foot%2BVDq%2B51SQXo1MFotGAGPNYrj2F%2BEvkloqVxU6j3iY9nImnrRHHd60zzS%2F2nx0ltHsMg%3D%3D"

url = "http://apis.data.go.kr/1360000/AsosDalyInfoService/getWthrDataList?" + \
    "serviceKey={0}&numOfRows={1}&dataCd={2}&dateCd={3}&startDt={4}&endDt={5}&stnIds={6}"\
    .format(api_key, 40, "ASOS", "DAY", 20240921, 20241021, 108)


request = urllib.request.Request(url)

response = urllib.request.urlopen(request) 
rescode = response.getcode() 
if rescode == 200: 
    response_body = response.read() 
    print(response_body.decode('utf-8')) 
else:
    print("Error Code:" + str(rescode))
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# ...

# %%
! pip install xmltodict

# %%
import xmltodict
data_dict = xmltodict.parse(response_body)
data_dict
# Out:
# {'response': {'header': {'resultCode': '00', 'resultMsg': 'NORMAL_SERVICE'},
#   'body': {'dataType': 'XML',
#    'items': {'item': [{'stnId': '108',
#       'stnNm': '서울',
#       'tm': '2024-09-21',
#       'avgTa': '19.3',
#       'minTa': '17.1',
#       'minTaHrmt': '0749',
#       'maxTa': '21.9',
#       'maxTaHrmt': '1528',
#       'mi10MaxRn': '4.9',
#       'mi10MaxRnHrmt': '613',
#       'hr1MaxRn': '10.4',
#       'hr1MaxRnHrmt': '745',
#       'sumRnDur': '8.83',
#       'sumRn': '27.0',
#       'maxInsWs': '12.2',
#       'maxInsWsWd': '50',
#       'maxInsWsHrmt': '0747',
#       'maxWs': '7.0',
#       'maxWsWd': '50',
#       'maxWsHrmt': '0254',
#       'avgWs': '4.3',
#       'hr24SumRws': '3734',
#       'maxWd': '50',
#       'avgTd': '16.0',
#       'minRhm': '69',
#       'minRhmHrmt': '1741',
#       'avgRhm': '82.3',
#       'avgPv': '18.2',
#       'avgPa': '997.4',
#       'maxPs': '1008.9',
#       'maxPsHrmt': '2245',
#       'minPs': '1006.2',
# ...

# %%
df_weather = pd.DataFrame(data_dict['response']['body']['items']['item'])

# %%
df_weather.head()
# Out:
#   stnId stnNm          tm avgTa minTa minTaHrmt maxTa maxTaHrmt mi10MaxRn  \
# 0   108    서울  2024-09-21  19.3  17.1      0749  21.9      1528       4.9
# 1   108    서울  2024-09-22  21.0  16.9      0523  26.7      1520      None
# 2   108    서울  2024-09-23  20.8  16.6      0603  26.1      1544      None
# 3   108    서울  2024-09-24  21.0  15.6      0638  26.9      1535      None
# 4   108    서울  2024-09-25  23.3  18.6      0312  27.3      1424       0.0
#
#   mi10MaxRnHrmt  ... avgM05Te avgM10Te avgM15Te avgM30Te avgM50Te sumLrgEv  \
# 0           613  ...     27.3     26.5     25.9     21.7     19.1      1.8
# 1          None  ...     26.0     26.4     26.3     21.9     19.1      4.5
# 2          None  ...     25.6     26.1     26.2     22.1     19.1      4.5
# 3          None  ...     25.2     25.8     26.1     22.0     19.2      4.4
# 4          None  ...     24.9     25.5     25.9     22.0     19.2      2.5
#
# ...

# %%
df_weather_1 = df_weather[['stnNm', 'tm', 'minTa', 'maxTa', 'avgTa']]
df_weather_1
# Out:
#    stnNm          tm minTa maxTa avgTa
# 0     서울  2024-09-21  17.1  21.9  19.3
# 1     서울  2024-09-22  16.9  26.7  21.0
# 2     서울  2024-09-23  16.6  26.1  20.8
# 3     서울  2024-09-24  15.6  26.9  21.0
# 4     서울  2024-09-25  18.6  27.3  23.3
# 5     서울  2024-09-26  21.1  28.0  23.6
# 6     서울  2024-09-27  19.1  28.0  22.7
# 7     서울  2024-09-28  19.2  27.9  23.2
# 8     서울  2024-09-29  19.1  29.0  23.5
# 9     서울  2024-09-30  18.3  28.5  23.0
# 10    서울  2024-10-01  13.3  21.7  18.3
# 11    서울  2024-10-02  11.6  19.9  14.9
# 12    서울  2024-10-03  10.8  22.5  16.4
# 13    서울  2024-10-04  11.9  24.2  17.6
# 14    서울  2024-10-05  11.6  24.4  17.5
# 15    서울  2024-10-06  12.3  17.9  15.4
# 16    서울  2024-10-07  14.0  20.7  16.9
# 17    서울  2024-10-08  12.7  23.9  17.7
# 18    서울  2024-10-09  13.9  24.4  18.8
# 19    서울  2024-10-10  15.3  24.1  18.8
# 20    서울  2024-10-11  13.9  24.4  18.6
# 21    서울  2024-10-12  13.4  24.7  18.3
# 22    서울  2024-10-13  12.6  22.6  18.3
# ...

# %%
df_weather_1['minTa'] = df_weather_1['minTa'].astype(float)
df_weather_1['maxTa'] = df_weather_1['maxTa'].astype(float)
df_weather_1['avgTa'] = df_weather_1['avgTa'].astype(float)
# Out:
# C:\Users\human\AppData\Local\Temp\ipykernel_1904\80000920.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_weather_1['minTa'] = df_weather_1['minTa'].astype(float)
# C:\Users\human\AppData\Local\Temp\ipykernel_1904\80000920.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_weather_1['maxTa'] = df_weather_1['maxTa'].astype(float)
# C:\Users\human\AppData\Local\Temp\ipykernel_1904\80000920.py:3: SettingWithCopyWarning:
# ...

# %%
df_weather_1.dtypes
# Out:
# stnNm     object
# tm        object
# minTa    float64
# maxTa    float64
# avgTa    float64
# dtype: object

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.ticker import MaxNLocator

df_weather_1['tm'] = pd.to_datetime(df_weather_1['tm'])

import matplotlib.pyplot as plt
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False

plt.figure(figsize=(15, 5))
plt.plot(df_weather_1['tm'], df_weather_1['avgTa'], marker='o', label = 'avg')
plt.plot(df_weather_1['tm'], df_weather_1['minTa'], marker='o', label = 'min')
plt.plot(df_weather_1['tm'], df_weather_1['maxTa'], marker='o', label = 'max')
plt.title('일별 평균 기온')
plt.xlabel('날짜')
plt.ylabel('평균 기온 (°C)')
plt.gca().xaxis.set_major_locator(mdates.DayLocator())
plt.gca().yaxis.set_major_locator(MaxNLocator(nbins=10))
plt.xticks(rotation=45)
plt.legend()
plt.grid()
plt.show()
# Out:
# C:\Users\human\AppData\Local\Temp\ipykernel_1904\1409184777.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_weather_1['tm'] = pd.to_datetime(df_weather_1['tm'])

# %%
df_weather_1.dtypes
# Out:
# stnNm            object
# tm       datetime64[ns]
# minTa           float64
# maxTa           float64
# avgTa           float64
# dtype: object

# %%
import requests

service_key = 'ym1IV1jj6wtrAIK/oot+VDq+51SQXo1MFotGAGPNYrj2F+EvkloqVxU6j3iY9nImnrRHHd60zzS/2nx0ltHsMg=='

url = 'http://apis.data.go.kr/B552584/MsrstnInfoInqireSvc/getMsrstnList'
params ={'serviceKey' : service_key, 'returnType' : 'json', 'numOfRows' : '500', 'pageNo' : '1' }

response = requests.get(url, params=params)
print(response.content)
# Out:
# b'{"response":{"body":{"totalCount":661,"items":[{"dmX":"37.012575","item":"SO2, CO, O3, NO2, PM10, PM2.5","mangName":"\xed\x95\xad\xeb\xa7\x8c","year":"2019","addr":"\xec\xb6\xa9\xeb\x82\xa8 \xec\x84\x9c\xec\x82\xb0\xec\x8b\x9c \xeb\x8c\x80\xec\x82\xb0\xec\x9d\x8d \xeb\x8c\x80\xec\xa3\xbd\xeb\xa6\xac 1114 \xeb\x8c\x80\xec\x82\xb0\xed\x95\xad \xea\xb3\xb5\xec\x9b\x90\xeb\xb6\x80\xec\xa7\x80","stationName":"\xeb\x8c\x80\xec\x82\xb0\xed\x95\xad","dmY":"126.426621"},{"dmX":"36.00799","item":"SO2, CO, O3, NO2, PM10, PM2.5","mangName":"\xed\x95\xad\xeb\xa7\x8c","year":"2019","addr":"\xec\xb6\xa9\xeb\x82\xa8 \xec\x84\x9c\xec\xb2\x9c\xea\xb5\xb0 \xec\x9e\xa5\xed\x95\xad\xec\x9d\x8d \xec\x9e\xa5\xec\x82\xb0\xeb\xa1\x9c 270-3 \xec\x9e\xa5\xed\x95\xad\xed\x95\xb4\xec\x96\x91\xec\x88\x98\xec\x82\xb0\xec\x82\xac\xeb\xac\xb4\xec\x86\x8c \xec\x98\xa5\xec\x83\x81","stationName":"\xec\x9e\xa5\xed\x95\xad\xed\x95\xad","dmY":"126.690312"},{"dmX":"36.98556","item":"SO2, CO, O3, NO2, PM10, PM2.5","mangN
# ...

# %%
# binary format -> text format 변경
decoded_response_content = response.content.decode('utf-8')
decoded_response_content
# Out:
# '{"response":{"body":{"totalCount":661,"items":[{"dmX":"37.012575","item":"SO2, CO, O3, NO2, PM10, PM2.5","mangName":"항만","year":"2019","addr":"충남 서산시 대산읍 대죽리 1114 대산항 공원부지","stationName":"대산항","dmY":"126.426621"},{"dmX":"36.00799","item":"SO2, CO, O3, NO2, PM10, PM2.5","mangName":"항만","year":"2019","addr":"충남 서천군 장항읍 장산로 270-3 장항해양수산사무소 옥상","stationName":"장항항","dmY":"126.690312"},{"dmX":"36.98556","item":"SO2, CO, O3, NO2, PM10, PM2.5","mangName":"항만","year":"2021","addr":"충남 당진시 송악읍 고대공단2길 79-30 고대관리부두 내","stationName":"평택당진항(당진항)","dmY":"126.746821"},{"dmX":"36.898586","item":"SO2, CO, O3, NO2, PM10, PM2.5","mangName":"항만","year":"2023","addr":"충남 태안군 원북면 발전로 457 한국서부발전내","stationName":"태안항","dmY":"126.239162"},{"dmX":"36.401527","item":"SO2, CO, O3, NO2, PM10, PM2.5","mangName":"항만","year":"2022","addr":"충남 보령시 오천면 오천해안로 89-37 보령발전소 내","stationName":"보령항","dmY":"126.487455"},{"dmX":"36.592906","item":"SO2, CO, O3, NO2, PM10, PM2.5","mangName":"도시대기","year":"2015","addr":"세종 조치원읍 
# ...

# %%
import json

# json string -> dict 변환
dict_content = json.loads(decoded_response_content)
dict_content
# Out:
# {'response': {'body': {'totalCount': 661,
#    'items': [{'dmX': '37.012575',
#      'item': 'SO2, CO, O3, NO2, PM10, PM2.5',
#      'mangName': '항만',
#      'year': '2019',
#      'addr': '충남 서산시 대산읍 대죽리 1114 대산항 공원부지',
#      'stationName': '대산항',
#      'dmY': '126.426621'},
#     {'dmX': '36.00799',
#      'item': 'SO2, CO, O3, NO2, PM10, PM2.5',
#      'mangName': '항만',
#      'year': '2019',
#      'addr': '충남 서천군 장항읍 장산로 270-3 장항해양수산사무소 옥상',
#      'stationName': '장항항',
#      'dmY': '126.690312'},
#     {'dmX': '36.98556',
#      'item': 'SO2, CO, O3, NO2, PM10, PM2.5',
#      'mangName': '항만',
#      'year': '2021',
#      'addr': '충남 당진시 송악읍 고대공단2길 79-30 고대관리부두 내',
#      'stationName': '평택당진항(당진항)',
#      'dmY': '126.746821'},
#     {'dmX': '36.898586',
#      'item': 'SO2, CO, O3, NO2, PM10, PM2.5',
#      'mangName': '항만',
#      'year': '2023',
#      'addr': '충남 태안군 원북면 발전로 457 한국서부발전내',
#      'stationName': '태안항',
#      'dmY': '126.239162'},
# ...

# %%
dict_content['response']['body']['items']
# Out:
# [{'dmX': '37.012575',
#   'item': 'SO2, CO, O3, NO2, PM10, PM2.5',
#   'mangName': '항만',
#   'year': '2019',
#   'addr': '충남 서산시 대산읍 대죽리 1114 대산항 공원부지',
#   'stationName': '대산항',
#   'dmY': '126.426621'},
#  {'dmX': '36.00799',
#   'item': 'SO2, CO, O3, NO2, PM10, PM2.5',
#   'mangName': '항만',
#   'year': '2019',
#   'addr': '충남 서천군 장항읍 장산로 270-3 장항해양수산사무소 옥상',
#   'stationName': '장항항',
#   'dmY': '126.690312'},
#  {'dmX': '36.98556',
#   'item': 'SO2, CO, O3, NO2, PM10, PM2.5',
#   'mangName': '항만',
#   'year': '2021',
#   'addr': '충남 당진시 송악읍 고대공단2길 79-30 고대관리부두 내',
#   'stationName': '평택당진항(당진항)',
#   'dmY': '126.746821'},
#  {'dmX': '36.898586',
#   'item': 'SO2, CO, O3, NO2, PM10, PM2.5',
#   'mangName': '항만',
#   'year': '2023',
#   'addr': '충남 태안군 원북면 발전로 457 한국서부발전내',
#   'stationName': '태안항',
#   'dmY': '126.239162'},
#  {'dmX': '36.401527',
#   'item': 'SO2, CO, O3, NO2, PM10, PM2.5',
#   'mangName': '항만',
#   'year': '2022',
#   'addr': '충남 보령시 오천면 오천해안로 89-37 보령발전소 내',
# ...

# %%
import pandas as pd

df_content = pd.DataFrame(dict_content['response']['body']['items'])
df_content[['stationName', 'addr']]
# Out:
#     stationName                                   addr
# 0           대산항           충남 서산시 대산읍 대죽리 1114 대산항 공원부지
# 1           장항항      충남 서천군 장항읍 장산로 270-3 장항해양수산사무소 옥상
# 2    평택당진항(당진항)       충남 당진시 송악읍 고대공단2길 79-30 고대관리부두 내
# 3           태안항             충남 태안군 원북면 발전로 457 한국서부발전내
# 4           보령항         충남 보령시 오천면 오천해안로 89-37 보령발전소 내
# ..          ...                                    ...
# 495         본오동  경기도 안산시 상록구 오목로7길 15 본오1동 작은도서관 (본오동)
# 496         원곡동      경기도 안산시 단원구 부부로6길 17 근로자운동장 (원곡동)
# 497        부곡동1          경기 안산시 상록구 성호로 326 부곡동 행정복지센터
# 498         대부동       경기 안산시 단원구 대부중앙로 97-9 대부동 행정복지센터
# 499         호수동             경기 안산시 단원구 안산천남로 119 양지중학교
#
# [500 rows x 2 columns]

# %%
import requests

service_key = 'ym1IV1jj6wtrAIK/oot+VDq+51SQXo1MFotGAGPNYrj2F+EvkloqVxU6j3iY9nImnrRHHd60zzS/2nx0ltHsMg=='

url = 'http://apis.data.go.kr/B552584/ArpltnStatsSvc/getMsrstnAcctoRDyrg'
params ={'serviceKey' : service_key, 'returnType' : 'json', 'numOfRows' : '500', 'pageNo' : '1', 'inqBginDt' : '20240901', 'inqEndDt' : '20240930', 'msrstnName' : '금천구'}

response = requests.get(url, params=params)
print(response.content)
# Out:
# b'{"response":{"body":{"totalCount":30,"items":[{"msurDt":"2024-09-01","so2Value":".003","coValue":".4","msrstnName":"\xea\xb8\x88\xec\xb2\x9c\xea\xb5\xac","pm10Value":"29","no2Value":".013","o3Value":".047","pm25Value":"20"},{"msurDt":"2024-09-02","so2Value":".003","coValue":".4","msrstnName":"\xea\xb8\x88\xec\xb2\x9c\xea\xb5\xac","pm10Value":"18","no2Value":".016","o3Value":".032","pm25Value":"11"},{"msurDt":"2024-09-03","so2Value":".002","coValue":".3","msrstnName":"\xea\xb8\x88\xec\xb2\x9c\xea\xb5\xac","pm10Value":"10","no2Value":".009","o3Value":".05","pm25Value":"5"},{"msurDt":"2024-09-04","so2Value":".003","coValue":".3","msrstnName":"\xea\xb8\x88\xec\xb2\x9c\xea\xb5\xac","pm10Value":"16","no2Value":".016","o3Value":".055","pm25Value":"11"},{"msurDt":"2024-09-05","so2Value":".003","coValue":".3","msrstnName":"\xea\xb8\x88\xec\xb2\x9c\xea\xb5\xac","pm10Value":"21","no2Value":".018","o3Value":".037","pm25Value":"14"},{"msurDt":"2024-09-06","so2Value":".002","coValue":".3","msrst
# ...

# %%
decoded_response = response.content.decode('utf-8')
decoded_response
# Out:
# '{"response":{"body":{"totalCount":30,"items":[{"msurDt":"2024-09-01","so2Value":".003","coValue":".4","msrstnName":"금천구","pm10Value":"29","no2Value":".013","o3Value":".047","pm25Value":"20"},{"msurDt":"2024-09-02","so2Value":".003","coValue":".4","msrstnName":"금천구","pm10Value":"18","no2Value":".016","o3Value":".032","pm25Value":"11"},{"msurDt":"2024-09-03","so2Value":".002","coValue":".3","msrstnName":"금천구","pm10Value":"10","no2Value":".009","o3Value":".05","pm25Value":"5"},{"msurDt":"2024-09-04","so2Value":".003","coValue":".3","msrstnName":"금천구","pm10Value":"16","no2Value":".016","o3Value":".055","pm25Value":"11"},{"msurDt":"2024-09-05","so2Value":".003","coValue":".3","msrstnName":"금천구","pm10Value":"21","no2Value":".018","o3Value":".037","pm25Value":"14"},{"msurDt":"2024-09-06","so2Value":".002","coValue":".3","msrstnName":"금천구","pm10Value":"8","no2Value":".015","o3Value":".022","pm25Value":"10"},{"msurDt":"2024-09-07","so2Value":".003","coValue":".4","msrstnName":"금천구","pm10Valu
# ...

# %%
import json
dict_response = json.loads(decoded_response)
dict_response
# Out:
# {'response': {'body': {'totalCount': 30,
#    'items': [{'msurDt': '2024-09-01',
#      'so2Value': '.003',
#      'coValue': '.4',
#      'msrstnName': '금천구',
#      'pm10Value': '29',
#      'no2Value': '.013',
#      'o3Value': '.047',
#      'pm25Value': '20'},
#     {'msurDt': '2024-09-02',
#      'so2Value': '.003',
#      'coValue': '.4',
#      'msrstnName': '금천구',
#      'pm10Value': '18',
#      'no2Value': '.016',
#      'o3Value': '.032',
#      'pm25Value': '11'},
#     {'msurDt': '2024-09-03',
#      'so2Value': '.002',
#      'coValue': '.3',
#      'msrstnName': '금천구',
#      'pm10Value': '10',
#      'no2Value': '.009',
#      'o3Value': '.05',
#      'pm25Value': '5'},
#     {'msurDt': '2024-09-04',
#      'so2Value': '.003',
#      'coValue': '.3',
#      'msrstnName': '금천구',
#      'pm10Value': '16',
#      'no2Value': '.016',
#      'o3Value': '.055',
#      'pm25Value': '11'},
#     {'msurDt': '2024-09-05',
#      'so2Value': '.003',
#      'coValue': '.3',
# ...

# %%
dict_response['response']['body']['items']
# Out:
# [{'msurDt': '2024-09-01',
#   'so2Value': '.003',
#   'coValue': '.4',
#   'msrstnName': '금천구',
#   'pm10Value': '29',
#   'no2Value': '.013',
#   'o3Value': '.047',
#   'pm25Value': '20'},
#  {'msurDt': '2024-09-02',
#   'so2Value': '.003',
#   'coValue': '.4',
#   'msrstnName': '금천구',
#   'pm10Value': '18',
#   'no2Value': '.016',
#   'o3Value': '.032',
#   'pm25Value': '11'},
#  {'msurDt': '2024-09-03',
#   'so2Value': '.002',
#   'coValue': '.3',
#   'msrstnName': '금천구',
#   'pm10Value': '10',
#   'no2Value': '.009',
#   'o3Value': '.05',
#   'pm25Value': '5'},
#  {'msurDt': '2024-09-04',
#   'so2Value': '.003',
#   'coValue': '.3',
#   'msrstnName': '금천구',
#   'pm10Value': '16',
#   'no2Value': '.016',
#   'o3Value': '.055',
#   'pm25Value': '11'},
#  {'msurDt': '2024-09-05',
#   'so2Value': '.003',
#   'coValue': '.3',
#   'msrstnName': '금천구',
#   'pm10Value': '21',
#   'no2Value': '.018',
#   'o3Value': '.037',
#   'pm25Value': '14'},
#  {'msurDt': '2024-09-06',
# ...

# %%
import pandas as pd

df_data = pd.DataFrame(dict_response['response']['body']['items'])
df_data
# Out:
#         msurDt so2Value coValue msrstnName pm10Value no2Value o3Value  \
# 0   2024-09-01     .003      .4        금천구        29     .013    .047
# 1   2024-09-02     .003      .4        금천구        18     .016    .032
# 2   2024-09-03     .002      .3        금천구        10     .009     .05
# 3   2024-09-04     .003      .3        금천구        16     .016    .055
# 4   2024-09-05     .003      .3        금천구        21     .018    .037
# 5   2024-09-06     .002      .3        금천구         8     .015    .022
# 6   2024-09-07     .003      .4        금천구        19     .015    .042
# 7   2024-09-08     .003      .5        금천구        29     .015    .057
# 8   2024-09-09     .003      .5        금천구        28      .02    .045
# 9   2024-09-10     .002      .4        금천구        28     .022    .043
# 10  2024-09-11     .003      .4        금천구        26     .021    .045
# 11  2024-09-12     .003      .4        금천구         8     .019    .009
# ...

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   msurDt      30 non-null     object
#  1   so2Value    30 non-null     object
#  2   coValue     30 non-null     object
#  3   msrstnName  30 non-null     object
#  4   pm10Value   30 non-null     object
#  5   no2Value    30 non-null     object
#  6   o3Value     30 non-null     object
#  7   pm25Value   30 non-null     object
# dtypes: object(8)
# memory usage: 2.0+ KB

# %%
df_data['msurDt'] = pd.to_datetime(df_data['msurDt'])
df_data['pm10Value'] = df_data['pm10Value'].astype(int)
df_data['pm25Value'] = df_data['pm25Value'].astype(int)

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   msurDt      30 non-null     datetime64[ns]
#  1   so2Value    30 non-null     object
#  2   coValue     30 non-null     object
#  3   msrstnName  30 non-null     object
#  4   pm10Value   30 non-null     int64
#  5   no2Value    30 non-null     object
#  6   o3Value     30 non-null     object
#  7   pm25Value   30 non-null     int64
# dtypes: datetime64[ns](1), int64(2), object(5)
# memory usage: 2.0+ KB

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

import matplotlib.pyplot as plt
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False

plt.figure(figsize = (16, 5))
plt.plot(df_data['msurDt'], df_data['pm10Value'], marker = 'o', label = 'pm10')
plt.plot(df_data['msurDt'], df_data['pm25Value'], marker = 'o', label = 'pm25')
plt.title('10월 금천구 미세먼지 평균농도')
plt.xlabel('날짜')
plt.ylabel('미세먼지 평균농도')
plt.gca().xaxis.set_major_locator(mdates.DayLocator())
plt.xticks(rotation = 45)
plt.grid()
plt.legend()
plt.show()
